# %% [markdown]
# # Battle of Neighbourhoods: A Case study of two Major Financial hubs in their Countries

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# The City of Johannesburg in South Africa is a major hub for economic activity in the country and is the financial centre of Africa’s most industrialised economy. Similar to Toronto in Canada, they are the financial capital centres as well as largest GDP contributors in their countries respectively. Toronto contributes about 20% to the GDP of Canada while Johannesburg contributes about 14%. Though the two countries are major contributors to the economies the size of the contribution varies vastly with GDP per capita of Toronto being 36000 US dollars and the GDP per capita for Johannesburg being 3000 US dollars GDP per capita. In a world where economies are fluid and international work opportunities are available for the skilled and mobile working professionals; as well as to investors looking to diversify their investments, understanding neighbourhoods in the two cities can be used as a marketing tool to help attract skilled contributors to the countries economy in the form of visitors, investors or as a way to boost local economy by the locals.

# %% [markdown]
# ### 1.2 Problem

# %% [markdown]
# The Financial Districts of Johannesburg and Toronto are by nature and design present a flurry of financial activities and attractions, stemming from the fact that the financial industry has been and continues to engine of growth and wealth in economies across the World. This study explores how an individual living or a  visitor to the two cities is likely to experience the neighbourhoods surrounding the two financial districts. The two financial districts will be indexed by the Johannesburg Stock Exchange and the Toronto Stock Exchange for Johannesburg and Toronot respectively.

# %% [markdown]
# ### 1.3 Interest

# %% [markdown]
# The study of the two financial districts would be of particular interest to, a working professional, looking to enrich their local experience (South African/Canadian), a visitor looking to enrich their international experience of South Africa or Toronto, or an investor conducting research to assess viability for a financial investment project.

# %% [markdown]
# ## 2 Data Acquistion and Cleaning

# %% [markdown]
# ### 2.1 Data Acquisition

# %% [markdown]
# For the Initial starting points of the two financial districts the Google search engine was used to determine the address of the stock exchnage buildings. For the Toronto Stock Exchange, the Google search engine was further used to obtain the GPS coordinates of the building. For all data pertaining the project reliance was placed on the Foursquare API for input into the exploration and analysis work.

# %% [markdown]
# ### 2.2 Feature Selection

# %% [markdown]
# After extensive research and exploration of Foursquare API documentation, I settled on 3 API's to use for the study in this project. These are Building, Entertainment and Restaurant API’s. Selection of these API's in my view will be able to provide one with high level information and also directionally will be able to make educated decisions regarding neighbourhoods of the two financial districts.

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# As the study is an exploration study with reliance on on built in Python function. Neccesary libraries needed to perform analysis needed to be imported. The next section imports the relevant Python Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt


print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting geopy
#   Using cached geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.1.0
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/geographiclib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/geopy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/geographiclib-1.52.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/geopy-2.1.0.dist-info already exists. Specify --upgrade to force replacement.
# Processing ./.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8/folium-0.5.0-py3-none-any.whl
# Collecting branca
#   Using cached branca-0.4.2-py3-none-any.whl (24 kB)
# Collecting requests
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting jinja2
#   Using cached Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# ERROR: conda 4.8.2 requires ruamel_yaml>=0.11.14, which is not installed.
# ERROR: tensorflow 2.1.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.0 which is incompatible.
# ERROR: botocore 1.16.11 has requirement urllib3<1.26,>=1.20, but you'll have urllib3 1.26.6 which is incompatible.
# ERROR: aiohttp 3.6.2 has requirement chardet<4.0,>=2.0, but you'll have chardet 4.0.0 which is incompatible.
# Installing collected packages: MarkupSafe, jinja2, branca, idna, certifi, chardet, urllib3, requests, six, folium
# Successfully installed MarkupSafe-2.0.1 branca-0.4.2 certifi-2021.5.30 chardet-4.0.0 folium-0.5.0 idna-2.10 jinja2-3.0.1 requests-2.25.1 six-1.16.0 urllib3-1.26.6
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/idna-2.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/markupsafe already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/branca already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/folium-0.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/branca-0.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/requests-2.25.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/Jinja2-3.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/jinja2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/certifi-2021.5.30.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/MarkupSafe-2.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/chardet-4.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/idna already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/requests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/certifi already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/urllib3-1.26.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/chardet already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/folium already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/spark/shared/user-libs/python3.7/bin already exists. Specify --upgrade to force replacement.
# Folium installed
# Libraries imported.

# %%
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.2.2

# %% [markdown]
# #### Adding Personal Credentials to use and Foursquare

# %%
CLIENT_ID = 'XP5V0UWY5UNHLA1PLLNKBCGTZCVKXNQIMFLB5BCTUMN3TXMC' # your Foursquare ID
CLIENT_SECRET = 'C0FGSOMMZL20PS3GZJ24N54TVVQAKMG1HKA1GL1YMPLMQPUU' # your Foursquare Secret
ACCESS_TOKEN = '1UUHMKB3ZBYQ3GVUNHWDRV3VFWZPBOT4YEWSTCO0EMXFYW2N' # your FourSquare Access Token

VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XP5V0UWY5UNHLA1PLLNKBCGTZCVKXNQIMFLB5BCTUMN3TXMC
# CLIENT_SECRET:C0FGSOMMZL20PS3GZJ24N54TVVQAKMG1HKA1GL1YMPLMQPUU

# %% [markdown]
# ## 3.1 Exploring Buildings around the Johannesburg Stock Exchange

# %% [markdown]
# Using the address obtained from the Google Search engine as input, the below program seeks to find the GPS coordinates of the Johannesburg stock exchnage building in South Africa.

# %%
address = '2 Gwen Ln, Sandown, Sandton, 2196, South Africa'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -26.1021936 28.0565306

# %% [markdown]
# ### 3.1.1 Determining Exploration Radius from the Johannesburg Stock Exchange

# %%
query = 'Building'
radius = 1000
print(query + ' .... OK!')
# Out:
# Building .... OK!

# %%
url_JSE = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, query, radius, LIMIT)

# %%
import requests

# %%
results_JSE = requests.get(url_JSE).json()

# %%
'There are {} Buildings around the Johannesburg Stock Exchange.'.format(len(results_JSE['response']['groups'][0]['items']))
# Out:
# 'There are 6 Buildings around the Johannesburg Stock Exchange.'

# %% [markdown]
# ### 3.1.2. Formating Results

# %%
items_JSE = results_JSE['response']['groups'][0]['items']

# %%
dataframe_JSE = pd.json_normalize(items_JSE) # flatten JSON

# %% [markdown]
# ### 3.1.3. Displaying Summary Results

# %%
dataframe_JSE.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4b05870df964a520547d22e3-0              0
# 1  e-0-4bdf22f17ea362b52f5943c4-1              0
# 2  e-0-4b06d37ef964a520f9f022e3-2              0
# 3  e-0-4e0c8ee6d1646f1517874c2e-3              0
# 4  e-0-4ce43f0e42f0b1f7b2448cce-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                                venue.name  \
# 0  4b05870df964a520547d22e3                    Protea Hotel Balalaika
# 1  4bdf22f17ea362b52f5943c4  Hydro Park on Grayston Apartment Sandton
# 2  4b06d37ef964a520f9f022e3                              Sandton City
# 3  4e0c8ee6d1646f1517874c2e                       Michelangelo Towers
# 4  4ce43f0e42f0b1f7b2448cce                    Wall Street Restaurant
#
#   venue.location.address  venue.location.lat  venue.location.lng  \
# 0  Maude Street, Sandown          -26.103978           28.058131
# 1      86 Grayston Drive          -26.099973           28.053730
# 2             Rivonia Rd          -26.108566           28.052848
# 3         Sandown Valley          -26.106438           28.054180
# 4                    NaN          -26.102887           28.060970
#
#                        venue.location.labeledLatLngs  venue.location.distance  \
# 0  [{'label': 'display', 'lat': -26.1039778, 'lng...                      255
# 1  [{'label': 'display', 'lat': -26.0999725344602...                      373
# 2                                                NaN                      799
# 3  [{'label': 'display', 'lat': -26.1064382621836...                      527
# 4  [{'label': 'display', 'lat': -26.1028865600020...                      450
#
#    ... venue.location.cc venue.location.neighborhood venue.location.city  \
# 0  ...                ZA                     Sandown             Sandton
# 1  ...                ZA                         NaN             Sandton
# 2  ...                ZA                         NaN             Sandton
# 3  ...                ZA                         NaN             Sandton
# 4  ...                ZA                         NaN                 NaN
#
#   venue.location.state venue.location.country  \
# 0                ZA-GT      iNingizimu Afrika
# 1             IGauteng      iNingizimu Afrika
# 2             IGauteng      iNingizimu Afrika
# 3             IGauteng      iNingizimu Afrika
# 4                  NaN      iNingizimu Afrika
#
#                 venue.location.formattedAddress  \
# 0        [Maude Street, Sandown, Sandton, 2126]
# 1                  [86 Grayston Drive, Sandton]
# 2  [Rivonia Rd (cnr Sandton Dr), Sandton, 2196]
# 3      [Sandown Valley (Maude street), Sandton]
# 4                                           NaN
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                  0
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                  0
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...                  0
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                  0
# 4  [{'id': '4bf58dd8d48988d1c8941735', 'name': 'A...                  0
#
#    venue.photos.groups venue.location.crossStreet
# 0                   []                        NaN
# 1                   []                        NaN
# 2                   []             cnr Sandton Dr
# 3                   []               Maude street
# 4                   []                        NaN
#
# [5 rows x 21 columns]

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_JSE.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_JSE = dataframe_JSE.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_JSE['venue.categories'] = dataframe_filtered_JSE.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_JSE.columns = [col.split('.')[-1] for col in dataframe_filtered_JSE.columns]

dataframe_filtered_JSE.head(10)
# Out:
#                                        name          categories  \
# 0                    Protea Hotel Balalaika               Hotel
# 1  Hydro Park on Grayston Apartment Sandton               Hotel
# 2                              Sandton City       Shopping Mall
# 3                       Michelangelo Towers               Hotel
# 4                    Wall Street Restaurant  African Restaurant
# 5                          InterContinental               Hotel
#
#                         address        lat        lng  \
# 0         Maude Street, Sandown -26.103978  28.058131
# 1             86 Grayston Drive -26.099973  28.053730
# 2                    Rivonia Rd -26.108566  28.052848
# 3                Sandown Valley -26.106438  28.054180
# 4                           NaN -26.102887  28.060970
# 5  Corner of Maude & 5th Street -26.106805  28.052569
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -26.1039778, 'lng...       255       2126  ZA
# 1  [{'label': 'display', 'lat': -26.0999725344602...       373        NaN  ZA
# 2                                                NaN       799       2196  ZA
# 3  [{'label': 'display', 'lat': -26.1064382621836...       527        NaN  ZA
# 4  [{'label': 'display', 'lat': -26.1028865600020...       450        NaN  ZA
# 5  [{'label': 'display', 'lat': -26.1068045365651...       648       2146  ZA
#
#   neighborhood     city     state            country  \
# 0      Sandown  Sandton     ZA-GT  iNingizimu Afrika
# 1          NaN  Sandton  IGauteng  iNingizimu Afrika
# 2          NaN  Sandton  IGauteng  iNingizimu Afrika
# 3          NaN  Sandton  IGauteng  iNingizimu Afrika
# 4          NaN      NaN       NaN  iNingizimu Afrika
# 5          NaN  Sandton  IGauteng  iNingizimu Afrika
#
#                                 formattedAddress     crossStreet  \
# 0         [Maude Street, Sandown, Sandton, 2126]             NaN
# 1                   [86 Grayston Drive, Sandton]             NaN
# 2   [Rivonia Rd (cnr Sandton Dr), Sandton, 2196]  cnr Sandton Dr
# 3       [Sandown Valley (Maude street), Sandton]    Maude street
# 4                                            NaN             NaN
# 5  [Corner of Maude & 5th Street, Sandton, 2146]             NaN
#
#                          id
# 0  4b05870df964a520547d22e3
# 1  4bdf22f17ea362b52f5943c4
# 2  4b06d37ef964a520f9f022e3
# 3  4e0c8ee6d1646f1517874c2e
# 4  4ce43f0e42f0b1f7b2448cce
# 5  4b05870df964a5202b7d22e3

# %%
print(dataframe_filtered_JSE.columns.tolist())
# Out:
# ['name', 'categories', 'address', 'lat', 'lng', 'labeledLatLngs', 'distance', 'postalCode', 'cc', 'neighborhood', 'city', 'state', 'country', 'formattedAddress', 'crossStreet', 'id']

# %% [markdown]
# ### 3.1.4 Displaying a Formatted Data points of interests from the Results

# %%
dataframe_2 = dataframe_filtered_JSE.iloc [:, 0:5]

# %%
dataframe_2
# Out:
#                                        name          categories  \
# 0                    Protea Hotel Balalaika               Hotel
# 1  Hydro Park on Grayston Apartment Sandton               Hotel
# 2                              Sandton City       Shopping Mall
# 3                       Michelangelo Towers               Hotel
# 4                    Wall Street Restaurant  African Restaurant
# 5                          InterContinental               Hotel
#
#                         address        lat        lng
# 0         Maude Street, Sandown -26.103978  28.058131
# 1             86 Grayston Drive -26.099973  28.053730
# 2                    Rivonia Rd -26.108566  28.052848
# 3                Sandown Valley -26.106438  28.054180
# 4                           NaN -26.102887  28.060970
# 5  Corner of Maude & 5th Street -26.106805  28.052569

# %% [markdown]
# ## 3.2 Exploring Buildings around Toronto Stock Exchange

# %% [markdown]
# ### 3.2.1 Adding Toronto Stock Exchange Address

# %%
address = '130 King St W, Toronto, ON M5X 2A2, Canada'

geolocator = Nominatim(user_agent="foursquare_agent")
location =  geolocator.geocode(address)
latitude_2 = 43.648550 #location.latitude
longitude_2 = -79.383304 #location.longitude
print(latitude_2, longitude_2)
# Out:
# 43.64855 -79.383304

# %%
query = 'Building'
radius_1 = 1000
print(query + ' .... OK!')
# Out:
# Building .... OK!

# %%
url_TSX = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2,ACCESS_TOKEN, VERSION, query, radius_1, LIMIT)

# %% [markdown]
# ### 3.2.2. Formating Results

# %%
import requests

# %%
results_TSX = requests.get(url_TSX).json()

# %%
'There are {} buildings around the Toronto Stock Exchange.'.format(len(results_TSX['response']['groups'][0]['items']))
# Out:
# 'There are 65 buildings around the Toronto Stock Exchange.'

# %%
items_TSX = results_TSX['response']['groups'][0]['items']

# %%
dataframe_TSX = pd.json_normalize(items_TSX) # flatten JSON

# %% [markdown]
# ### 3.2.3. Displaying Results

# %%
dataframe_TSX.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4ad4c05ef964a5208ef620e3-0              0
# 1  e-0-4adb896df964a520bf2821e3-1              0
# 2  e-0-4ad4c05ef964a520daf620e3-2              0
# 3  e-0-4bcf714ab221c9b67f0ad2d0-3              0
# 4  e-0-4ad4c05ef964a52096f620e3-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id              venue.name venue.location.address  \
# 0  4ad4c05ef964a5208ef620e3           Old City Hall   60 Queen Street West
# 1  4adb896df964a520bf2821e3            401 Richmond      401 Richmond St W
# 2  4ad4c05ef964a520daf620e3  Art Gallery of Ontario        317 Dundas St W
# 3  4bcf714ab221c9b67f0ad2d0      TIFF Bell Lightbox         350 King St. W
# 4  4ad4c05ef964a52096f620e3                CN Tower         301 Front St W
#
#    venue.location.lat  venue.location.lng  \
# 0           43.652009          -79.381744
# 1           43.647906          -79.395219
# 2           43.654003          -79.392922
# 3           43.646342          -79.390063
# 4           43.642277          -79.387055
#
#                        venue.location.labeledLatLngs  venue.location.distance  \
# 0  [{'label': 'display', 'lat': 43.65200880087612...                      405
# 1  [{'label': 'display', 'lat': 43.64790630817995...                      962
# 2  [{'label': 'display', 'lat': 43.65400286033738...                      984
# 3  [{'label': 'display', 'lat': 43.64634159071232...                      597
# 4                                                NaN                      760
#
#    ... venue.location.city venue.location.state venue.location.country  \
# 0  ...             Toronto                   ON                 Canada
# 1  ...             Toronto                   ON                 Canada
# 2  ...             Toronto                   ON                 Canada
# 3  ...             Toronto                   ON                 Canada
# 4  ...             Toronto                   ON                 Canada
#
#                      venue.location.formattedAddress  \
# 0  [60 Queen Street West, Toronto ON M5H 1A1, Can...
# 1  [401 Richmond St W (at Spadina Ave), Toronto O...
# 2  [317 Dundas St W (at Beverley St), Toronto ON ...
# 3  [350 King St. W (at John St.), Toronto ON M5V ...
# 4  [301 Front St W (at John St), Toronto ON M5V 2...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d12d941735', 'name': 'M...                  0
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...                  0
# 2  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...                  0
# 3  [{'id': '4bf58dd8d48988d17f941735', 'name': 'M...                  0
# 4  [{'id': '4bf58dd8d48988d12d941735', 'name': 'M...                  0
#
#   venue.photos.groups  venue.location.crossStreet venue.venuePage.id  \
# 0                  []                         NaN                NaN
# 1                  []              at Spadina Ave           33863999
# 2                  []              at Beverley St           33853777
# 3                  []                 at John St.           34450648
# 4                  []                  at John St           33864000
#
#   venue.location.neighborhood
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3      Entertainment District
# 4      Entertainment District
#
# [5 rows x 22 columns]

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_TSX.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_TSX = dataframe_TSX.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_TSX['venue.categories'] = dataframe_filtered_TSX.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_TSX.columns = [col.split('.')[-1] for col in dataframe_filtered_TSX.columns]

dataframe_filtered_TSX.head(10)
# Out:
#                                           name           categories  \
# 0                                Old City Hall  Monument / Landmark
# 1                                 401 Richmond          Art Gallery
# 2                       Art Gallery of Ontario          Art Gallery
# 3                           TIFF Bell Lightbox        Movie Theater
# 4                                     CN Tower  Monument / Landmark
# 5                       Nathan Phillips Square                Plaza
# 6  Four Seasons Centre for the Performing Arts         Concert Hall
# 7                             Roy Thomson Hall         Concert Hall
# 8                              Design Exchange          Art Gallery
# 9                         First Canadian Place             Building
#
#                 address        lat        lng  \
# 0  60 Queen Street West  43.652009 -79.381744
# 1     401 Richmond St W  43.647906 -79.395219
# 2       317 Dundas St W  43.654003 -79.392922
# 3        350 King St. W  43.646342 -79.390063
# 4        301 Front St W  43.642277 -79.387055
# 5        100 Queen St W  43.652270 -79.383516
# 6       145 Queen St. W  43.650592 -79.385806
# 7          60 Simcoe St  43.646589 -79.385979
# 8           234 Bay St.  43.647972 -79.380104
# 9         100 King St W  43.648482 -79.382443
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65200880087612...       405    M5H 1A1  CA
# 1  [{'label': 'display', 'lat': 43.64790630817995...       962    M5V 3A8  CA
# 2  [{'label': 'display', 'lat': 43.65400286033738...       984    M5T 1G4  CA
# 3  [{'label': 'display', 'lat': 43.64634159071232...       597    M5V 3X5  CA
# 4                                                NaN       760    M5V 2T6  CA
# 5  [{'label': 'display', 'lat': 43.65227047322295...       414    M5H 2N1  CA
# 6  [{'label': 'display', 'lat': 43.650592, 'lng':...       303    M5H 4G1  CA
# 7  [{'label': 'display', 'lat': 43.6465886970634,...       306    M5J 2H5  CA
# 8  [{'label': 'display', 'lat': 43.64797219581623...       265    M5K 1B2  CA
# 9  [{'label': 'display', 'lat': 43.64848212292913...        69    M5J 1W9  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [60 Queen Street West, Toronto ON M5H 1A1, Can...
# 1  Toronto    ON  Canada  [401 Richmond St W (at Spadina Ave), Toronto O...
# 2  Toronto    ON  Canada  [317 Dundas St W (at Beverley St), Toronto ON ...
# 3  Toronto    ON  Canada  [350 King St. W (at John St.), Toronto ON M5V ...
# 4  Toronto    ON  Canada  [301 Front St W (at John St), Toronto ON M5V 2...
# 5  Toronto    ON  Canada  [100 Queen St W (at Bay St), Toronto ON M5H 2N...
# 6  Toronto    ON  Canada  [145 Queen St. W (at University Ave.), Toronto...
# 7  Toronto    ON  Canada  [60 Simcoe St (at King St W), Toronto ON M5J 2...
# 8  Toronto    ON  Canada  [234 Bay St. (btwn King & Wellington), Toronto...
# 9  Toronto    ON  Canada  [100 King St W (btwn Bay & University), Toront...
#
#               crossStreet            neighborhood                        id
# 0                     NaN                     NaN  4ad4c05ef964a5208ef620e3
# 1          at Spadina Ave                     NaN  4adb896df964a520bf2821e3
# 2          at Beverley St                     NaN  4ad4c05ef964a520daf620e3
# 3             at John St.  Entertainment District  4bcf714ab221c9b67f0ad2d0
# 4              at John St  Entertainment District  4ad4c05ef964a52096f620e3
# 5               at Bay St                     NaN  4ad4c05ef964a520a6f620e3
# 6      at University Ave.                     NaN  4ad4c062f964a520e5f720e3
# 7            at King St W                     NaN  4ad4c061f964a520b0f720e3
# 8  btwn King & Wellington                     NaN  4ad4c05ff964a520eff620e3
# 9   btwn Bay & University                     NaN  4ad4c063f964a52020f820e3

# %% [markdown]
# ### 3.2.4 Displaying a Formatted Data points of interests from the Results

# %%
dataframe_filtered_TSX_1 = dataframe_filtered_TSX.iloc [:,0:5]

# %%
dataframe_filtered_TSX_1
# Out:
#                            name                categories  \
# 0                 Old City Hall       Monument / Landmark
# 1                  401 Richmond               Art Gallery
# 2        Art Gallery of Ontario               Art Gallery
# 3            TIFF Bell Lightbox             Movie Theater
# 4                      CN Tower       Monument / Landmark
# ..                          ...                       ...
# 60              Storys Building                Restaurant
# 61         Union Station Market                    Market
# 62  Loft404 Inspired Gatherings               Event Space
# 63    Union Station Platform 27                  Platform
# 64                Feta & Olives  Mediterranean Restaurant
#
#                   address        lat        lng
# 0    60 Queen Street West  43.652009 -79.381744
# 1       401 Richmond St W  43.647906 -79.395219
# 2         317 Dundas St W  43.654003 -79.392922
# 3          350 King St. W  43.646342 -79.390063
# 4          301 Front St W  43.642277 -79.387055
# ..                    ...        ...        ...
# 60          11 Duncan St.  43.647552 -79.388318
# 61                    NaN  43.645630 -79.381130
# 62  263 Adelaide St. West  43.647851 -79.389490
# 63         65 Front St. W  43.643952 -79.380496
# 64        Pinnacle Centre  43.643451 -79.375566
#
# [65 rows x 5 columns]

# %%
Building_categories = dataframe_filtered_TSX_1['categories'].unique()

# %% [markdown]
# ### 3.2.5 Creating a Frequency Table for the Data points of interests from the Results

# %%
TSX_Building_categories =  dataframe_filtered_TSX_1.groupby('categories')['categories'].size().reset_index(name='counts').sort_values(['counts','categories'],ascending = [False,True])

# %%
TSX_Building_categories
# Out:
#                                   categories  counts
# 20                                     Hotel       8
# 11                               Coffee Shop       4
# 0                                Art Gallery       3
# 12                              Concert Hall       3
# 14                          Department Store       2
# 15                               Event Space       2
# 16                            Farmers Market       2
# 28                       Monument / Landmark       2
# 29                             Movie Theater       2
# 31                                    Office       2
# 38                                Steakhouse       2
# 40                                   Theater       2
# 1                                       Bank       1
# 2                           Baseball Stadium       1
# 3                         Basketball Stadium       1
# 4                         Belgian Restaurant       1
# 5                                    Brewery       1
# 6                                   Building       1
# 7                                Bus Station       1
# 8                                       Café       1
# 9                                     Church       1
# 10                            Clothing Store       1
# 13                             Deli / Bodega       1
# 17                                Food Court       1
# 18                                 Gastropub       1
# 19                            General Travel       1
# 21                               IT Services       1
# 22                        Italian Restaurant       1
# 23                              Liquor Store       1
# 24                                    Lounge       1
# 25                                    Market       1
# 26                  Mediterranean Restaurant       1
# 27                             Metro Station       1
# 30                                    Museum       1
# 32                                  Platform       1
# 33                                     Plaza       1
# 34  Residential Building (Apartment / Condo)       1
# 35                                Restaurant       1
# 36                             Shopping Mall       1
# 37                                Sports Bar       1
# 39                          Sushi Restaurant       1
# 41                             Train Station       1
# 42                                University       1

# %% [markdown]
# ## 3.3 Exploring Entertainment spots around the Financial Districts

# %% [markdown]
# ### 3.3.1 Exploring Entertainment spots around the Financial District in Johannesburg (Johannesburg Stock Exchange)

# %%
query = 'Entertainment'
radius_1 = 1000
print(query + ' .... OK!')
# Out:
# Entertainment .... OK!

# %%
url_JSE_fun = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, query, radius, LIMIT)

# %% [markdown]
# ### 3.3.2. Formatting Results for Entertainment spots around the Johannesburg Stock Exchange

# %%
results_JSE_fun = requests.get(url_JSE_fun).json()

# %%
'There are {} areas of enterainment around the Johannesburg Stock Exchange.'.format(len(results_JSE_fun['response']['groups'][0]['items']))
# Out:
# 'There are 4 areas of enterainment around the Johannesburg Stock Exchange.'

# %%
items_JSE_fun = results_JSE_fun['response']['groups'][0]['items']

# %%
dataframe_JSE_fun = pd.json_normalize(items_JSE_fun) # flatten JSON

# %% [markdown]
# ### 3.3.3. Displaying Results for Entertainment spots around the Johannesburg Stock Exchange

# %%
dataframe_JSE_fun.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4bc9b94a937ca593c82ca692-0              0
# 1  e-0-4bc10821f8219c74e1bab210-1              0
# 2  e-0-50aa5d8ae4b0a68d85ecd45b-2              0
# 3  e-0-4ee32b25be7b4845a30985a6-3              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                   venue.name  \
# 0  4bc9b94a937ca593c82ca692      Harley Davidson Sandton
# 1  4bc10821f8219c74e1bab210                        Taboo
# 2  50aa5d8ae4b0a68d85ecd45b                    The Venue
# 3  4ee32b25be7b4845a30985a6  Sandton City Fountain Court
#
#   venue.location.address venue.location.crossStreet  venue.location.lat  \
# 0       167 Rivonia road                   Grayston          -26.095784
# 1             24 Central   Cnr Fredman Dr & Gwen Ln          -26.101860
# 2             Green Park                 Lower Road          -26.096407
# 3                    NaN                        NaN          -26.107452
#
#    venue.location.lng                      venue.location.labeledLatLngs  \
# 0           28.056061  [{'label': 'display', 'lat': -26.0957839571620...
# 1           28.057470  [{'label': 'display', 'lat': -26.1018604279674...
# 2           28.053734  [{'label': 'display', 'lat': -26.0964066688268...
# 3           28.054710  [{'label': 'display', 'lat': -26.1074522861225...
#
#    venue.location.distance venue.location.cc venue.location.city  \
# 0                      715                ZA             Sandton
# 1                      100                ZA             Sandton
# 2                      702                ZA             Sandton
# 3                      613                ZA                 NaN
#
#   venue.location.state venue.location.country  \
# 0             IGauteng      iNingizimu Afrika
# 1             IGauteng      iNingizimu Afrika
# 2             IGauteng      iNingizimu Afrika
# 3                  NaN      iNingizimu Afrika
#
#                      venue.location.formattedAddress  \
# 0             [167 Rivonia road (Grayston), Sandton]
# 1  [24 Central (Cnr Fredman Dr & Gwen Ln), Sandto...
# 2                 [Green Park (Lower Road), Sandton]
# 3                                                NaN
#
#                                     venue.categories  venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                   0
# 1  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...                   0
# 2  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                   0
# 3  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                   0
#
#   venue.photos.groups venue.location.postalCode
# 0                  []                       NaN
# 1                  []                      2196
# 2                  []                       NaN
# 3                  []                       NaN

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_JSE_fun.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_JSE_fun = dataframe_JSE_fun.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_JSE_fun['venue.categories'] = dataframe_filtered_JSE_fun.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_JSE_fun.columns = [col.split('.')[-1] for col in dataframe_filtered_JSE_fun.columns]

dataframe_filtered_JSE_fun.head(10)
# Out:
#                           name             categories           address  \
# 0      Harley Davidson Sandton  General Entertainment  167 Rivonia road
# 1                        Taboo              Nightclub        24 Central
# 2                    The Venue  General Entertainment        Green Park
# 3  Sandton City Fountain Court  General Entertainment               NaN
#
#                 crossStreet        lat        lng  \
# 0                  Grayston -26.095784  28.056061
# 1  Cnr Fredman Dr & Gwen Ln -26.101860  28.057470
# 2                Lower Road -26.096407  28.053734
# 3                       NaN -26.107452  28.054710
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': -26.0957839571620...       715  ZA  Sandton
# 1  [{'label': 'display', 'lat': -26.1018604279674...       100  ZA  Sandton
# 2  [{'label': 'display', 'lat': -26.0964066688268...       702  ZA  Sandton
# 3  [{'label': 'display', 'lat': -26.1074522861225...       613  ZA      NaN
#
#       state            country  \
# 0  IGauteng  iNingizimu Afrika
# 1  IGauteng  iNingizimu Afrika
# 2  IGauteng  iNingizimu Afrika
# 3       NaN  iNingizimu Afrika
#
#                                     formattedAddress postalCode  \
# 0             [167 Rivonia road (Grayston), Sandton]        NaN
# 1  [24 Central (Cnr Fredman Dr & Gwen Ln), Sandto...       2196
# 2                 [Green Park (Lower Road), Sandton]        NaN
# 3                                                NaN        NaN
#
#                          id
# 0  4bc9b94a937ca593c82ca692
# 1  4bc10821f8219c74e1bab210
# 2  50aa5d8ae4b0a68d85ecd45b
# 3  4ee32b25be7b4845a30985a6

# %% [markdown]
# ### 3.3.4. Displaying Data points of the Interest from the results set for Entertainment spots around the Johannesburg Stock Exchange

# %%
dataframe_JSE_entertain = dataframe_filtered_JSE_fun.iloc [:, 0:5]

# %%
dataframe_JSE_entertain
# Out:
#                           name             categories           address  \
# 0      Harley Davidson Sandton  General Entertainment  167 Rivonia road
# 1                        Taboo              Nightclub        24 Central
# 2                    The Venue  General Entertainment        Green Park
# 3  Sandton City Fountain Court  General Entertainment               NaN
#
#                 crossStreet        lat
# 0                  Grayston -26.095784
# 1  Cnr Fredman Dr & Gwen Ln -26.101860
# 2                Lower Road -26.096407
# 3                       NaN -26.107452

# %%
Entertainment_Categories_JHB = dataframe_JSE_entertain.groupby('categories')['categories'].size().reset_index(name='counts').sort_values(['counts','categories'],ascending = [False,True])
Entertainment_Categories_JHB
# Out:
#               categories  counts
# 0  General Entertainment       3
# 1              Nightclub       1

# %% [markdown]
# ## 3.4. Exploring Entertainment spots around the Financial District in Toronto (Toronto Stock Exchange)

# %% [markdown]
# ### 3.4.1. Executing the API for Exploring Entertainment spots around the Toronto Stock Exchange

# %%
url_TSX_fun = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2,ACCESS_TOKEN, VERSION, query, radius_1, LIMIT)

# %% [markdown]
# ### 3.4.2. Formatting Results for Entertainment spots around the Toronto Stock Exchange

# %%
results_TSX_fun = requests.get(url_TSX_fun).json()
results_TSX_fun
# Out:
# {'meta': {'code': 200, 'requestId': '60dd2ccdb5ab84411e701bfb'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Financial District',
#   'headerFullLocation': 'Financial District, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'entertainment',
#   'totalResults': 42,
#   'suggestedBounds': {'ne': {'lat': 43.65755000900001,
#     'lng': -79.37088918065864},
#    'sw': {'lat': 43.63954999099999, 'lng': -79.39571881934135}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5033a657e4b0c160f748c5ab',
#        'name': 'TIFF Festival Box Office',
#        'location': {'address': '225 King St. W',
#         'crossStreet': 'in Metro Centre',
#         'lat': 43.64688731930244,
#         'lng': -79.38788483304397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64688731930244,
#           'lng': -79.38788483304397}],
#         'distance': 412,
#         'postalCode': 'M5V 3C7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['225 King St. W (in Metro Centre)',
#          'Toronto ON M5V 3C7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5033a657e4b0c160f748c5ab-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd32bdea8b3a593de3e695f',
#        'name': 'FITC Toronto',
#        'location': {'address': '145 Richmond St. W',
#         'crossStreet': 'at University Ave.',
#         'lat': 43.64987248299678,
#         'lng': -79.38574511590106,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64987248299678,
#           'lng': -79.38574511590106}],
#         'distance': 245,
#         'postalCode': 'M5H 2L2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 Richmond St. W (at University Ave.)',
#          'Toronto ON M5H 2L2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd32bdea8b3a593de3e695f-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a520b5f720e3',
#        'name': 'Elgin And Winter Garden Theatres',
#        'location': {'address': '189 Yonge St',
#         'crossStreet': 'btwn Queen St E & Shuter St',
#         'lat': 43.653393796019586,
#         'lng': -79.3785073962175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653393796019586,
#           'lng': -79.3785073962175}],
#         'distance': 663,
#         'postalCode': 'M5B 2H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['189 Yonge St (btwn Queen St E & Shuter St)',
#          'Toronto ON M5B 2H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c062f964a520b5f720e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c061f964a520aef720e3',
#        'name': 'Princess Of Wales Theatre',
#        'location': {'address': '300 King St. W',
#         'crossStreet': 'at John St.',
#         'lat': 43.64654315405365,
#         'lng': -79.38910030187289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64654315405365,
#           'lng': -79.38910030187289}],
#         'distance': 517,
#         'postalCode': 'M5V 1J2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['300 King St. W (at John St.)',
#          'Toronto ON M5V 1J2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c061f964a520aef720e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a52096f620e3',
#        'name': 'CN Tower',
#        'location': {'address': '301 Front St W',
#         'crossStreet': 'at John St',
#         'lat': 43.642277432828145,
#         'lng': -79.38705542070056,
#         'distance': 760,
#         'postalCode': 'M5V 2T6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['301 Front St W (at John St)',
#          'Toronto ON M5V 2T6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33864000'}},
#       'referralId': 'e-0-4ad4c05ef964a52096f620e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a520bbf720e3',
#        'name': 'Royal Alexandra Theatre',
#        'location': {'address': '260 King St W',
#         'crossStreet': 'at Duncan St',
#         'lat': 43.647255,
#         'lng': -79.38753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647255,
#           'lng': -79.38753}],
#         'distance': 369,
#         'postalCode': 'M5V 1H9',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['260 King St W (at Duncan St)',
#          'Toronto ON M5V 1H9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32823702'}},
#       'referralId': 'e-0-4ad4c062f964a520bbf720e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6a001df964a520dbc02be3',
#        'name': 'Albany Club of Toronto',
#        'location': {'address': '91 King St. E',
#         'crossStreet': 'at Church St.',
#         'lat': 43.64956374719146,
#         'lng': -79.37492272179233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64956374719146,
#           'lng': -79.37492272179233}],
#         'distance': 684,
#         'postalCode': 'M5C 1G3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['91 King St. E (at Church St.)',
#          'Toronto ON M5C 1G3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6a001df964a520dbc02be3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a520e5f720e3',
#        'name': 'Four Seasons Centre for the Performing Arts',
#        'location': {'address': '145 Queen St. W',
#         'crossStreet': 'at University Ave.',
#         'lat': 43.650592,
#         'lng': -79.385806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650592,
#           'lng': -79.385806}],
#         'distance': 303,
#         'postalCode': 'M5H 4G1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 Queen St. W (at University Ave.)',
#          'Toronto ON M5H 4G1',
#          'Canada']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c062f964a520e5f720e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf714ab221c9b67f0ad2d0',
#        'name': 'TIFF Bell Lightbox',
#        'location': {'address': '350 King St. W',
#         'crossStreet': 'at John St.',
#         'lat': 43.64634159071232,
#         'lng': -79.39006297129853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64634159071232,
#           'lng': -79.39006297129853}],
#         'distance': 597,
#         'postalCode': 'M5V 3X5',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['350 King St. W (at John St.)',
#          'Toronto ON M5V 3X5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34450648'}},
#       'referralId': 'e-0-4bcf714ab221c9b67f0ad2d0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b155081f964a520b4b023e3',
#        'name': 'Scotiabank Arena',
#        'location': {'address': '40 Bay St',
#         'lat': 43.64344617535107,
#         'lng': -79.37903988889991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64344617535107,
#           'lng': -79.37903988889991}],
#         'distance': 663,
#         'postalCode': 'M5J 2X2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 Bay St', 'Toronto ON M5J 2X2', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d18b941735',
#          'name': 'Basketball Stadium',
#          'pluralName': 'Basketball Stadiums',
#          'shortName': 'Basketball',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_basketball_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33431410'}},
#       'referralId': 'e-0-4b155081f964a520b4b023e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e777fcc814ddff25f2112f0',
#        'name': 'LG Fashion Week (David Pecaut Square)',
#        'location': {'address': '221 King St West',
#         'crossStreet': 'at John St',
#         'lat': 43.64647053232912,
#         'lng': -79.38755025003927,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64647053232912,
#           'lng': -79.38755025003927}],
#         'distance': 413,
#         'postalCode': 'M5J 2H5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['221 King St West (at John St)',
#          'Toronto ON M5J 2H5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e777fcc814ddff25f2112f0-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c064f964a52061f820e3',
#        'name': 'Toronto Maple Leafs Hockey Club',
#        'location': {'address': '40 Bay Street',
#         'lat': 43.645786474455754,
#         'lng': -79.37980311832982,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.645786474455754,
#           'lng': -79.37980311832982}],
#         'distance': 417,
#         'postalCode': 'M5J 2X2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 Bay Street', 'Toronto ON M5J 2X2', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c064f964a52061f820e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c22423599282d7f23d366b0',
#        'name': 'JL Recording Studios',
#        'location': {'address': '270 Adelaide Street West, Suite 202',
#         'crossStreet': 'at John St',
#         'lat': 43.64799155218117,
#         'lng': -79.38936460164057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64799155218117,
#           'lng': -79.38936460164057}],
#         'distance': 492,
#         'postalCode': 'M5H 1X6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['270 Adelaide Street West, Suite 202 (at John St)',
#          'Toronto ON M5H 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '80477915'}},
#       'referralId': 'e-0-4c22423599282d7f23d366b0-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '547a6aa3498e156b225a1f43',
#        'name': 'Cavalcade of Lights',
#        'location': {'address': 'Nathan Phillips Sq',
#         'lat': 43.65257115735955,
#         'lng': -79.38314617590945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65257115735955,
#           'lng': -79.38314617590945}],
#         'distance': 447,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Nathan Phillips Sq', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-547a6aa3498e156b225a1f43-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8b823c0c422d439e570b31',
#        'name': 'TwestivalTO @ The Fifth Social Club',
#        'location': {'address': '225 Richmond Street West',
#         'lat': 43.649429,
#         'lng': -79.388891,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649429,
#           'lng': -79.388891}],
#         'distance': 460,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['225 Richmond Street West',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8b823c0c422d439e570b31-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db6f8080437fa536a62de09',
#        'name': 'CTV',
#        'location': {'address': '260 Richmond St. W',
#         'lat': 43.64946809310048,
#         'lng': -79.38929120788336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64946809310048,
#           'lng': -79.38929120788336}],
#         'distance': 492,
#         'postalCode': 'M5V 1W5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['260 Richmond St. W',
#          'Toronto ON M5V 1W5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db6f8080437fa536a62de09-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf338916a31d13a8b75942e',
#        'name': 'CP24',
#        'location': {'address': '299 Queen St. W',
#         'crossStreet': 'at John St.',
#         'lat': 43.64965738867735,
#         'lng': -79.39014194194075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64965738867735,
#           'lng': -79.39014194194075}],
#         'distance': 564,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['299 Queen St. W (at John St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf338916a31d13a8b75942e-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1d962781dcef96cf1dc498',
#        'name': 'BRIDGE BETWEEN NORTH & SOUTH BLDG - MTCC - Level 400',
#        'location': {'address': '255 Front St W',
#         'crossStreet': 'one floor up from lvl 400/Skywalk',
#         'lat': 43.64331933468127,
#         'lng': -79.38559234142303,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64331933468127,
#           'lng': -79.38559234142303}],
#         'distance': 610,
#         'postalCode': 'M5V 2W6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Front St W (one floor up from lvl 400/Skywalk)',
#          'Toronto ON M5V 2W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1d962781dcef96cf1dc498-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d51d8d19d493704617bd139',
#        'name': 'Loft404 Inspired Gatherings',
#        'location': {'address': '263 Adelaide St. West',
#         'crossStreet': 'S/E side John & Adelaide, 4th Floor',
#         'lat': 43.64785142504536,
#         'lng': -79.38948982526453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64785142504536,
#           'lng': -79.38948982526453}],
#         'distance': 504,
#         'postalCode': 'M5H 1Y2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['263 Adelaide St. West (S/E side John & Adelaide, 4th Floor)',
#          'Toronto ON M5H 1Y2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'shortName': 'Event Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '56681363'}},
#       'referralId': 'e-0-4d51d8d19d493704617bd139-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f6aaca498ec00c08336a69',
#        'name': 'The Social',
#        'location': {'address': '299 Queen St. W',
#         'crossStreet': 'John St',
#         'lat': 43.64990081295334,
#         'lng': -79.39079956361627,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64990081295334,
#           'lng': -79.39079956361627}],
#         'distance': 622,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['299 Queen St. W (John St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51f6aaca498ec00c08336a69-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3132f5e4b08a0e6d3a2c44',
#        'name': 'The Marilyn Denis Show',
#        'location': {'address': '299 Queen Street W',
#         'crossStreet': 'John Street',
#         'lat': 43.649895119788226,
#         'lng': -79.39081973855983,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649895119788226,
#           'lng': -79.39081973855983}],
#         'distance': 623,
#         'postalCode': 'M5V 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['299 Queen Street W (John Street)',
#          'Toronto ON M5V 2Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3132f5e4b08a0e6d3a2c44-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd5b07f6f6495211e756fec',
#        'name': 'MuchMusic Studios',
#        'location': {'address': '299 Queen St. W',
#         'crossStreet': 'at John St.',
#         'lat': 43.64975767235513,
#         'lng': -79.39087677572508,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64975767235513,
#           'lng': -79.39087677572508}],
#         'distance': 624,
#         'postalCode': 'M5V 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['299 Queen St. W (at John St.)',
#          'Toronto ON M5V 2Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd5b07f6f6495211e756fec-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b40a19498e79d32092e868',
#        'name': '6ix Still',
#        'location': {'address': '8 front street',
#         'lat': 43.6475257,
#         'lng': -79.37566609999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6475257,
#           'lng': -79.37566609999999}],
#         'distance': 625,
#         'postalCode': 'M5E 1C9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['8 front street',
#          'Toronto ON M5E 1C9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '154822095'}},
#       'referralId': 'e-0-56b40a19498e79d32092e868-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9b9fc2971676b051375ee2',
#        'name': 'Kinect for Xbox 360 Experience Toronto',
#        'location': {'address': '207 Yonge Street',
#         'crossStreet': 'btw Dundas & Queen',
#         'lat': 43.65381444,
#         'lng': -79.37991142272719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65381444,
#           'lng': -79.37991142272719}],
#         'distance': 646,
#         'postalCode': 'm5b2h6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['207 Yonge Street (btw Dundas & Queen)',
#          'Toronto ON m5b2h6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9b9fc2971676b051375ee2-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f898859e4b0af4d4df2a72a',
#        'name': 'Comicon Toronto',
#        'location': {'address': '255 Front Street',
#         'lat': 43.64255266779754,
#         'lng': -79.38514639638804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64255266779754,
#           'lng': -79.38514639638804}],
#         'distance': 683,
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Front Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f898859e4b0af4d4df2a72a-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1dcc5181dcef96cf1de4bd',
#        'name': 'EXHIBIT HALL G - MTCC - South Bldg',
#        'location': {'address': '255 Front St W',
#         'crossStreet': 'Level 800',
#         'lat': 43.642552983578085,
#         'lng': -79.38517349427048,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.642552983578085,
#           'lng': -79.38517349427048}],
#         'distance': 684,
#         'postalCode': 'M5V 2W6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Front St W (Level 800)',
#          'Toronto ON M5V 2W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1dcc5181dcef96cf1de4bd-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bba7335b35776b039f6ca01',
#        'name': 'The Score Television Network',
#        'location': {'address': '370 King St. W',
#         'crossStreet': 'at Peters St.',
#         'lat': 43.64601740382962,
#         'lng': -79.39220701427395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64601740382962,
#           'lng': -79.39220701427395}],
#         'distance': 770,
#         'postalCode': 'M5V 1J9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['370 King St. W (at Peters St.)',
#          'Toronto ON M5V 1J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bba7335b35776b039f6ca01-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50494347d63eaea07a6c2daf',
#        'name': 'VISA Screening Room #TIFF',
#        'location': {'address': '189 Yonge St.',
#         'crossStreet': 'Elgin and Winter Garden Theatre Centre',
#         'lat': 43.6534148270092,
#         'lng': -79.37845854142398,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6534148270092,
#           'lng': -79.37845854142398}],
#         'distance': 667,
#         'postalCode': 'M5B 2H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['189 Yonge St. (Elgin and Winter Garden Theatre Centre)',
#          'Toronto ON M5B 2H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50494347d63eaea07a6c2daf-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538bf897498e8301b31e1e65',
#        'name': 'The Porch',
#        'location': {'address': '250 Adelaide Street West',
#         'crossStreet': 'Duncan Street',
#         'lat': 43.64825063999569,
#         'lng': -79.38900157428692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64825063999569,
#           'lng': -79.38900157428692}],
#         'distance': 460,
#         'postalCode': 'M5H 1X6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['250 Adelaide Street West (Duncan Street)',
#          'Toronto ON M5H 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-538bf897498e8301b31e1e65-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5952cf02829b0c59fa430f63',
#        'name': 'The Rec Room',
#        'location': {'address': '255 Bremner Blvd',
#         'lat': 43.641109851662456,
#         'lng': -79.38676279808568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.641109851662456,
#           'lng': -79.38676279808568}],
#         'distance': 873,
#         'postalCode': 'M5V 3M9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['255 Bremner Blvd',
#          'Toronto ON M5V 3M9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5952cf02829b0c59fa430f63-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b157f42f964a520b6ad23e3',
#        'name': 'Juniper Park',
#        'location': {'address': '33 Bloor St E',
#         'crossStreet': 'Yonge',
#         'lat': 43.647417789385386,
#         'lng': -79.39369098045694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647417789385386,
#           'lng': -79.39369098045694}],
#         'distance': 846,
#         'postalCode': 'M4W 3H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['33 Bloor St E (Yonge)',
#          'Toronto ON M4W 3H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43452616'}},
#       'referralId': 'e-0-4b157f42f964a520b6ad23e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51bb6bc5e4b0cbdc3353be8b',
#        'name': 'NXNE',
#        'location': {'lat': 43.65605123439563,
#         'lng': -79.38057291202202,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65605123439563,
#           'lng': -79.38057291202202}],
#         'distance': 863,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51bb6bc5e4b0cbdc3353be8b-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b193b23f964a520a4d923e3',
#        'name': 'David Pecaut Square',
#        'location': {'address': '225 King St. W',
#         'crossStreet': 'btwn Simcoe And John St.',
#         'lat': 43.646743128025875,
#         'lng': -79.38770055770874,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646743128025875,
#           'lng': -79.38770055770874}],
#         'distance': 407,
#         'postalCode': 'M5V 3C6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['225 King St. W (btwn Simcoe And John St.)',
#          'Toronto ON M5V 3C6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b193b23f964a520a4d923e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fdf94e498ea5a005330746',
#        'name': 'Captive',
#        'location': {'address': '43 Elm St',
#         'lat': 43.65740323234807,
#         'lng': -79.38367401607144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65740323234807,
#           'lng': -79.38367401607144}],
#         'distance': 985,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['43 Elm St', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fdf94e498ea5a005330746-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55b2f7bd498ecdbad2888ddc',
#        'name': 'Roundabout Canada',
#        'location': {'address': '330 Yonge Street',
#         'crossStreet': 'Edward St. & Yonge St.',
#         'lat': 43.657393681608724,
#         'lng': -79.38148856163025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.657393681608724,
#           'lng': -79.38148856163025}],
#         'distance': 995,
#         'postalCode': 'M5B 1R8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['330 Yonge Street (Edward St. & Yonge St.)',
#          'Toronto ON M5B 1R8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f1931735',
#          'name': 'General Entertainment',
#          'pluralName': 'General Entertainment',
#          'shortName': 'Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55b2f7bd498ecdbad2888ddc-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05df964a52060f620e3',
#        'name': 'The Reservoir Lounge',
#        'location': {'address': '52 Wellington St. E',
#         'crossStreet': 'btwn Church St. and Yonge St.',
#         'lat': 43.64851659851552,
#         'lng': -79.37455623391588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64851659851552,
#           'lng': -79.37455623391588}],
#         'distance': 704,
#         'postalCode': 'M5E 1C9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['52 Wellington St. E (btwn Church St. and Yonge St.)',
#          'Toronto ON M5E 1C9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'shortName': 'Jazz Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05df964a52060f620e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53361f24498e6a4d4d8f66f1',
#        'name': 'D.W. Alexander',
#        'location': {'address': '19 Church St',
#         'crossStreet': 'Front St. E.',
#         'lat': 43.64833304339161,
#         'lng': -79.3738261420116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64833304339161,
#           'lng': -79.3738261420116}],
#         'distance': 763,
#         'postalCode': 'M5E 1M2',
#         'cc': 'CA',
#         'neighborhood': 'St. Lawrence',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['19 Church St (Front St. E.)',
#          'Toronto ON M5E 1M2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53361f24498e6a4d4d8f66f1-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad7aa49f964a5207b0d21e3',
#        'name': 'Scotiabank Theatres',
#        'location': {'address': '259 Richmond St. W',
#         'crossStreet': 'John St',
#         'lat': 43.648829331652806,
#         'lng': -79.39078229912828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648829331652806,
#           'lng': -79.39078229912828}],
#         'distance': 603,
#         'postalCode': 'M5V 3M6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['259 Richmond St. W (John St)',
#          'Toronto ON M5V 3M6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad7aa49f964a5207b0d21e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cee80deb1466a31aabda8fe',
#        'name': 'The Ballroom',
#        'location': {'address': '145 John St.',
#         'crossStreet': 'at Richmond St. W',
#         'lat': 43.64900829333002,
#         'lng': -79.3905664599237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64900829333002,
#           'lng': -79.3905664599237}],
#         'distance': 587,
#         'postalCode': 'M5V 2E4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 John St. (at Richmond St. W)',
#          'Toronto ON M5V 2E4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e4931735',
#          'name': 'Bowling Alley',
#          'pluralName': 'Bowling Alleys',
#          'shortName': 'Bowling Alley',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/bowling_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55856468'}},
#       'referralId': 'e-0-4cee80deb1466a31aabda8fe-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b223f5af964a520ba4424e3',
#        'name': 'Azure Restaurant & Bar',
#        'location': {'address': '225 Front St W',
#         'crossStreet': 'in InterContinental Toronto Centre',
#         'lat': 43.644749195919346,
#         'lng': -79.38511295085902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.644749195919346,
#           'lng': -79.38511295085902}],
#         'distance': 447,
#         'postalCode': 'M5V 2X3',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['225 Front St W (in InterContinental Toronto Centre)',
#          'Toronto ON M5V 2X3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '136175835'}},
#       'referralId': 'e-0-4b223f5af964a520ba4424e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f46fc09e4b07d6fb1429631',
#        'name': 'CUBE',
#        'location': {'address': '314 Queen west',
#         'lat': 43.64959715841995,
#         'lng': -79.39421237825871,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64959715841995,
#           'lng': -79.39421237825871}],
#         'distance': 886,
#         'postalCode': 'M5V 2A2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['314 Queen west',
#          'Toronto ON M5V 2A2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f46fc09e4b07d6fb1429631-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05df964a52055f620e3',
#        'name': 'Bier Markt Esplanade',
#        'location': {'address': '58 The Esplanade',
#         'crossStreet': 'at Church St.',
#         'lat': 43.64723602476138,
#         'lng': -79.37389161769812,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64723602476138,
#           'lng': -79.37389161769812}],
#         'distance': 772,
#         'postalCode': 'M5E 1A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['58 The Esplanade (at Church St.)',
#          'Toronto ON M5E 1A6',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a02',
#          'name': 'Belgian Restaurant',
#          'pluralName': 'Belgian Restaurants',
#          'shortName': 'Belgian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05df964a52055f620e3-41'}]}]}}

# %%
'There are {} areas of enterainment around the Toronto Stock Exchange.'.format(len(results_TSX_fun['response']['groups'][0]['items']))
# Out:
# 'There are 42 areas of enterainment around the Toronto Stock Exchange.'

# %%
items_TSX_fun = results_TSX_fun['response']['groups'][0]['items']

# %%
dataframe_TSX_fun = pd.json_normalize(items_TSX_fun) # flatten JSON

# %%
dataframe_TSX_fun.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-5033a657e4b0c160f748c5ab-0              0
# 1  e-0-4bd32bdea8b3a593de3e695f-1              0
# 2  e-0-4ad4c062f964a520b5f720e3-2              0
# 3  e-0-4ad4c061f964a520aef720e3-3              0
# 4  e-0-4ad4c05ef964a52096f620e3-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                        venue.name  \
# 0  5033a657e4b0c160f748c5ab          TIFF Festival Box Office
# 1  4bd32bdea8b3a593de3e695f                      FITC Toronto
# 2  4ad4c062f964a520b5f720e3  Elgin And Winter Garden Theatres
# 3  4ad4c061f964a520aef720e3         Princess Of Wales Theatre
# 4  4ad4c05ef964a52096f620e3                          CN Tower
#
#   venue.location.address   venue.location.crossStreet  venue.location.lat  \
# 0         225 King St. W              in Metro Centre           43.646887
# 1     145 Richmond St. W           at University Ave.           43.649872
# 2           189 Yonge St  btwn Queen St E & Shuter St           43.653394
# 3         300 King St. W                  at John St.           43.646543
# 4         301 Front St W                   at John St           43.642277
#
#    venue.location.lng                      venue.location.labeledLatLngs  ...  \
# 0          -79.387885  [{'label': 'display', 'lat': 43.64688731930244...  ...
# 1          -79.385745  [{'label': 'display', 'lat': 43.64987248299678...  ...
# 2          -79.378507  [{'label': 'display', 'lat': 43.65339379601958...  ...
# 3          -79.389100  [{'label': 'display', 'lat': 43.64654315405365...  ...
# 4          -79.387055                                                NaN  ...
#
#    venue.location.cc venue.location.city venue.location.state  \
# 0                 CA             Toronto                   ON
# 1                 CA             Toronto                   ON
# 2                 CA             Toronto                   ON
# 3                 CA             Toronto                   ON
# 4                 CA             Toronto                   ON
#
#   venue.location.country                    venue.location.formattedAddress  \
# 0                 Canada  [225 King St. W (in Metro Centre), Toronto ON ...
# 1                 Canada  [145 Richmond St. W (at University Ave.), Toro...
# 2                 Canada  [189 Yonge St (btwn Queen St E & Shuter St), T...
# 3                 Canada  [300 King St. W (at John St.), Toronto ON M5V ...
# 4                 Canada  [301 Front St W (at John St), Toronto ON M5V 2...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                  0
# 1  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                  0
# 2  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...                  0
# 3  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...                  0
# 4  [{'id': '4bf58dd8d48988d12d941735', 'name': 'M...                  0
#
#   venue.photos.groups  venue.location.neighborhood venue.venuePage.id
# 0                  []                          NaN                NaN
# 1                  []                          NaN                NaN
# 2                  []                          NaN                NaN
# 3                  []                          NaN                NaN
# 4                  []       Entertainment District           33864000
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 3.4.3. Displaying Results for Entertainment spots around the Toronto Stock Exchange

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_TSX_fun.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_TSX_fun = dataframe_TSX_fun.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_TSX_fun['venue.categories'] = dataframe_filtered_TSX_fun.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_TSX_fun.columns = [col.split('.')[-1] for col in dataframe_filtered_TSX_fun.columns]

dataframe_filtered_TSX_fun.head(10)
# Out:
#                                           name             categories  \
# 0                     TIFF Festival Box Office  General Entertainment
# 1                                 FITC Toronto  General Entertainment
# 2             Elgin And Winter Garden Theatres                Theater
# 3                    Princess Of Wales Theatre  General Entertainment
# 4                                     CN Tower    Monument / Landmark
# 5                      Royal Alexandra Theatre  General Entertainment
# 6                       Albany Club of Toronto  General Entertainment
# 7  Four Seasons Centre for the Performing Arts           Concert Hall
# 8                           TIFF Bell Lightbox          Movie Theater
# 9                             Scotiabank Arena     Basketball Stadium
#
#               address                  crossStreet        lat        lng  \
# 0      225 King St. W              in Metro Centre  43.646887 -79.387885
# 1  145 Richmond St. W           at University Ave.  43.649872 -79.385745
# 2        189 Yonge St  btwn Queen St E & Shuter St  43.653394 -79.378507
# 3      300 King St. W                  at John St.  43.646543 -79.389100
# 4      301 Front St W                   at John St  43.642277 -79.387055
# 5       260 King St W                 at Duncan St  43.647255 -79.387530
# 6       91 King St. E                at Church St.  43.649564 -79.374923
# 7     145 Queen St. W           at University Ave.  43.650592 -79.385806
# 8      350 King St. W                  at John St.  43.646342 -79.390063
# 9           40 Bay St                          NaN  43.643446 -79.379040
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.64688731930244...       412    M5V 3C7  CA
# 1  [{'label': 'display', 'lat': 43.64987248299678...       245    M5H 2L2  CA
# 2  [{'label': 'display', 'lat': 43.65339379601958...       663    M5B 2H1  CA
# 3  [{'label': 'display', 'lat': 43.64654315405365...       517    M5V 1J2  CA
# 4                                                NaN       760    M5V 2T6  CA
# 5  [{'label': 'display', 'lat': 43.647255, 'lng':...       369    M5V 1H9  CA
# 6  [{'label': 'display', 'lat': 43.64956374719146...       684    M5C 1G3  CA
# 7  [{'label': 'display', 'lat': 43.650592, 'lng':...       303    M5H 4G1  CA
# 8  [{'label': 'display', 'lat': 43.64634159071232...       597    M5V 3X5  CA
# 9  [{'label': 'display', 'lat': 43.64344617535107...       663    M5J 2X2  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [225 King St. W (in Metro Centre), Toronto ON ...
# 1  Toronto    ON  Canada  [145 Richmond St. W (at University Ave.), Toro...
# 2  Toronto    ON  Canada  [189 Yonge St (btwn Queen St E & Shuter St), T...
# 3  Toronto    ON  Canada  [300 King St. W (at John St.), Toronto ON M5V ...
# 4  Toronto    ON  Canada  [301 Front St W (at John St), Toronto ON M5V 2...
# 5  Toronto    ON  Canada  [260 King St W (at Duncan St), Toronto ON M5V ...
# 6  Toronto    ON  Canada  [91 King St. E (at Church St.), Toronto ON M5C...
# 7  Toronto    ON  Canada  [145 Queen St. W (at University Ave.), Toronto...
# 8  Toronto    ON  Canada  [350 King St. W (at John St.), Toronto ON M5V ...
# 9  Toronto    ON  Canada            [40 Bay St, Toronto ON M5J 2X2, Canada]
#
#              neighborhood                        id
# 0                     NaN  5033a657e4b0c160f748c5ab
# 1                     NaN  4bd32bdea8b3a593de3e695f
# 2                     NaN  4ad4c062f964a520b5f720e3
# 3                     NaN  4ad4c061f964a520aef720e3
# 4  Entertainment District  4ad4c05ef964a52096f620e3
# 5  Entertainment District  4ad4c062f964a520bbf720e3
# 6                     NaN  4b6a001df964a520dbc02be3
# 7                     NaN  4ad4c062f964a520e5f720e3
# 8  Entertainment District  4bcf714ab221c9b67f0ad2d0
# 9                     NaN  4b155081f964a520b4b023e3

# %% [markdown]
# ### 3.4.4. Displaying Data points of interest from the Results for Entertainment spots around the Toronto Stock Exchange

# %%
dataframe_filtered_TSX_fun_1 = dataframe_filtered_TSX_fun.iloc [:,0:5]

# %%
dataframe_filtered_TSX_fun_1
# Out:
#                                                  name             categories  \
# 0                            TIFF Festival Box Office  General Entertainment
# 1                                        FITC Toronto  General Entertainment
# 2                    Elgin And Winter Garden Theatres                Theater
# 3                           Princess Of Wales Theatre  General Entertainment
# 4                                            CN Tower    Monument / Landmark
# 5                             Royal Alexandra Theatre  General Entertainment
# 6                              Albany Club of Toronto  General Entertainment
# 7         Four Seasons Centre for the Performing Arts           Concert Hall
# 8                                  TIFF Bell Lightbox          Movie Theater
# 9                                    Scotiabank Arena     Basketball Stadium
# 10              LG Fashion Week (David Pecaut Square)  General Entertainment
# 11                    Toronto Maple Leafs Hockey Club  General Entertainment
# 12                               JL Recording Studios  General Entertainment
# 13                                Cavalcade of Lights  General Entertainment
# 14                TwestivalTO @ The Fifth Social Club  General Entertainment
# 15                                                CTV  General Entertainment
# 16                                               CP24  General Entertainment
# 17  BRIDGE BETWEEN NORTH & SOUTH BLDG - MTCC - Lev...  General Entertainment
# 18                        Loft404 Inspired Gatherings            Event Space
# 19                                         The Social  General Entertainment
# 20                             The Marilyn Denis Show  General Entertainment
# 21                                  MuchMusic Studios  General Entertainment
# 22                                          6ix Still  General Entertainment
# 23             Kinect for Xbox 360 Experience Toronto  General Entertainment
# 24                                    Comicon Toronto  General Entertainment
# 25                 EXHIBIT HALL G - MTCC - South Bldg  General Entertainment
# 26                       The Score Television Network  General Entertainment
# 27                          VISA Screening Room #TIFF          Movie Theater
# 28                                          The Porch                    Bar
# 29                                       The Rec Room                    Bar
# 30                                       Juniper Park  General Entertainment
# 31                                               NXNE  General Entertainment
# 32                                David Pecaut Square                   Park
# 33                                            Captive  General Entertainment
# 34                                  Roundabout Canada  General Entertainment
# 35                               The Reservoir Lounge              Jazz Club
# 36                                     D.W. Alexander           Cocktail Bar
# 37                                Scotiabank Theatres          Movie Theater
# 38                                       The Ballroom          Bowling Alley
# 39                             Azure Restaurant & Bar             Restaurant
# 40                                               CUBE              Nightclub
# 41                               Bier Markt Esplanade     Belgian Restaurant
#
#                                 address  \
# 0                        225 King St. W
# 1                    145 Richmond St. W
# 2                          189 Yonge St
# 3                        300 King St. W
# 4                        301 Front St W
# 5                         260 King St W
# 6                         91 King St. E
# 7                       145 Queen St. W
# 8                        350 King St. W
# 9                             40 Bay St
# 10                     221 King St West
# 11                        40 Bay Street
# 12  270 Adelaide Street West, Suite 202
# 13                   Nathan Phillips Sq
# 14             225 Richmond Street West
# 15                   260 Richmond St. W
# 16                      299 Queen St. W
# 17                       255 Front St W
# 18                263 Adelaide St. West
# 19                      299 Queen St. W
# 20                   299 Queen Street W
# 21                      299 Queen St. W
# 22                       8 front street
# 23                     207 Yonge Street
# 24                     255 Front Street
# 25                       255 Front St W
# 26                       370 King St. W
# 27                        189 Yonge St.
# 28             250 Adelaide Street West
# 29                     255 Bremner Blvd
# 30                        33 Bloor St E
# 31                                  NaN
# 32                       225 King St. W
# 33                            43 Elm St
# 34                     330 Yonge Street
# 35                  52 Wellington St. E
# 36                         19 Church St
# 37                   259 Richmond St. W
# 38                         145 John St.
# 39                       225 Front St W
# 40                       314 Queen west
# 41                     58 The Esplanade
#
#                                crossStreet        lat
# 0                          in Metro Centre  43.646887
# 1                       at University Ave.  43.649872
# 2              btwn Queen St E & Shuter St  43.653394
# 3                              at John St.  43.646543
# 4                               at John St  43.642277
# 5                             at Duncan St  43.647255
# 6                            at Church St.  43.649564
# 7                       at University Ave.  43.650592
# 8                              at John St.  43.646342
# 9                                      NaN  43.643446
# 10                              at John St  43.646471
# 11                                     NaN  43.645786
# 12                              at John St  43.647992
# 13                                     NaN  43.652571
# 14                                     NaN  43.649429
# 15                                     NaN  43.649468
# 16                             at John St.  43.649657
# 17       one floor up from lvl 400/Skywalk  43.643319
# 18     S/E side John & Adelaide, 4th Floor  43.647851
# 19                                 John St  43.649901
# 20                             John Street  43.649895
# 21                             at John St.  43.649758
# 22                                     NaN  43.647526
# 23                      btw Dundas & Queen  43.653814
# 24                                     NaN  43.642553
# 25                               Level 800  43.642553
# 26                           at Peters St.  43.646017
# 27  Elgin and Winter Garden Theatre Centre  43.653415
# 28                           Duncan Street  43.648251
# 29                                     NaN  43.641110
# 30                                   Yonge  43.647418
# 31                                     NaN  43.656051
# 32                btwn Simcoe And John St.  43.646743
# 33                                     NaN  43.657403
# 34                  Edward St. & Yonge St.  43.657394
# 35           btwn Church St. and Yonge St.  43.648517
# 36                            Front St. E.  43.648333
# 37                                 John St  43.648829
# 38                       at Richmond St. W  43.649008
# 39      in InterContinental Toronto Centre  43.644749
# 40                                     NaN  43.649597
# 41                           at Church St.  43.647236

# %%
#Understanding types of entertainment venues available in Toronto

Toronto_unique_entertainment= dataframe_filtered_TSX_fun_1['categories'].unique()

# %% [markdown]
# ### 3.4.5. Creating a Frequency Table for the Data points of interests from the Results of Entertainment spots around the Toronto Stock Exchange

# %%
TSX_entertainment_categories =  dataframe_filtered_TSX_fun_1.groupby('categories')['categories'].size().reset_index(name='counts').sort_values(['counts','categories'],ascending = [False,True])
TSX_entertainment_categories
# Out:
#                categories  counts
# 7   General Entertainment      25
# 10          Movie Theater       3
# 0                     Bar       2
# 1      Basketball Stadium       1
# 2      Belgian Restaurant       1
# 3           Bowling Alley       1
# 4            Cocktail Bar       1
# 5            Concert Hall       1
# 6             Event Space       1
# 8               Jazz Club       1
# 9     Monument / Landmark       1
# 11              Nightclub       1
# 12                   Park       1
# 13             Restaurant       1
# 14                Theater       1

# %% [markdown]
# # 3.5 Exploring Number of Restaurants around the Financial Districts

# %% [markdown]
# ### 3.5.1. Exploring Restaurants around the Johannesburg Financial District (Johannesburg Stock Exchange)

# %%
#Reducing the radius to 500 meters based on the fact that food spots should not be sparsely located as a result of the smaller footprint required to set them up
query = 'Restaurant'
radius_1 = 500
print(query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
LIMIT_2 = 500

# %%
url_JSE_food = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, query, radius_1, LIMIT_2)
url_JSE_food
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=XP5V0UWY5UNHLA1PLLNKBCGTZCVKXNQIMFLB5BCTUMN3TXMC&client_secret=C0FGSOMMZL20PS3GZJ24N54TVVQAKMG1HKA1GL1YMPLMQPUU&ll=-26.1021936,28.0565306&oauth_token=1UUHMKB3ZBYQ3GVUNHWDRV3VFWZPBOT4YEWSTCO0EMXFYW2N&v=20180604&query=Restaurant&radius=500&limit=500'

# %% [markdown]
# ### 3.5.2. Formatting Results for the Restaurants around the Johannesburg Financial District (Johannesburg Stock Exchange) API

# %%
results_JSE_food = requests.get(url_JSE_food).json()
results_JSE_food
# Out:
# {'meta': {'code': 200, 'requestId': '60dd2ce41c8b5132e9dde8ab'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'headerLocation': 'City of Johannesburg',
#   'headerFullLocation': 'City of Johannesburg',
#   'headerLocationGranularity': 'city',
#   'query': 'restaurant',
#   'totalResults': 34,
#   'suggestedBounds': {'ne': {'lat': -26.097693595499994,
#     'lng': 28.061532324720723},
#    'sw': {'lat': -26.106693604500006, 'lng': 28.051528875279274}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b79a0f856837a001cbf334c',
#        'name': 'Saint',
#        'location': {'lat': -26.10346672778748,
#         'lng': 28.059072452559565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10346672778748,
#           'lng': 28.059072452559565}],
#         'distance': 290,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton', '2196']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b79a0f856837a001cbf334c-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2cc3cd2219c928209ba648',
#        'name': 'Rocket Express',
#        'location': {'address': 'Maude Street',
#         'lat': -26.103395828277094,
#         'lng': 28.05882137871322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103395828277094,
#           'lng': 28.05882137871322}],
#         'distance': 265,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Maude Street', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2cc3cd2219c928209ba648-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be68e7ad4f7c9b63ddf2620',
#        'name': 'Pigalle',
#        'location': {'lat': -26.10606328983116,
#         'lng': 28.05427714177494,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10606328983116,
#           'lng': 28.05427714177494}],
#         'distance': 486,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be68e7ad4f7c9b63ddf2620-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba8ff50f964a520ea013ae3',
#        'name': 'The Bull Run',
#        'location': {'address': 'Maude Street',
#         'crossStreet': 'West Street',
#         'lat': -26.103709949471384,
#         'lng': 28.058277142616713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103709949471384,
#           'lng': 28.058277142616713}],
#         'distance': 242,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Maude Street (West Street)', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba8ff50f964a520ea013ae3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54967e59498e349305cfdbb1',
#        'name': 'Knead Bakery',
#        'location': {'address': 'Maude Street',
#         'lat': -26.106007571683943,
#         'lng': 28.054516016842406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.106007571683943,
#           'lng': 28.054516016842406}],
#         'distance': 469,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Maude Street', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54967e59498e349305cfdbb1-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51da603a498e78da6c48f58c',
#        'name': 'The Panini Brothers',
#        'location': {'address': 'Shop 6, 24 Cenbral',
#         'crossStreet': 'Gwen Lane and Fredman Drive',
#         'lat': -26.10172328478155,
#         'lng': 28.057038212067805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10172328478155,
#           'lng': 28.057038212067805}],
#         'distance': 72,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Shop 6, 24 Cenbral (Gwen Lane and Fredman Drive)',
#          'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51da603a498e78da6c48f58c-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daeabaaa86e29d01a481f5c',
#        'name': 'Europa Express Nedbank',
#        'location': {'lat': -26.102198700898526,
#         'lng': 28.058406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102198700898526,
#           'lng': 28.058406}],
#         'distance': 187,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4daeabaaa86e29d01a481f5c-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce97033b5c3594163c7698f',
#        'name': 'The Gourmet Garage Sandton burgers, steak, ribs, poultry great beers and coffee',
#        'location': {'address': '24 central, Gwen Lane',
#         'crossStreet': 'Fredman Drive and Gwen Lane',
#         'lat': -26.102423002054937,
#         'lng': 28.057541287329848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102423002054937,
#           'lng': 28.057541287329848}],
#         'distance': 104,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['24 central, Gwen Lane (Fredman Drive and Gwen Lane)',
#          'Sandton',
#          '2196']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce97033b5c3594163c7698f-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d77bf4e013060fcc7329c05',
#        'name': 'Fego Caffe RMB',
#        'location': {'address': 'Shop G01, RMB 2 Merchant Place, 1 Fredman Drive',
#         'lat': -26.100613,
#         'lng': 28.056982,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.100613,
#           'lng': 28.056982}],
#         'distance': 181,
#         'postalCode': '2146',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Shop G01, RMB 2 Merchant Place, 1 Fredman Drive',
#          'Sandton',
#          '2146']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d77bf4e013060fcc7329c05-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523c8ea4498ea7e0e8c4e4ba',
#        'name': 'Squires Loft',
#        'location': {'address': '24 Central',
#         'lat': -26.102299,
#         'lng': 28.056577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102299,
#           'lng': 28.056577}],
#         'distance': 12,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['24 Central', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523c8ea4498ea7e0e8c4e4ba-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bcbbef964a5207a6e2fe3',
#        'name': 'Gourmet Garage',
#        'location': {'address': '24 Central',
#         'crossStreet': 'Gwen Lane',
#         'lat': -26.10223578701332,
#         'lng': 28.05679498919582,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10223578701332,
#           'lng': 28.05679498919582}],
#         'distance': 26,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['24 Central (Gwen Lane)', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bcbbef964a5207a6e2fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d56dde7611aa35d3eb84639',
#        'name': 'HQ',
#        'location': {'address': '24 Central',
#         'crossStreet': 'Cnr. Gwen Ln. & Fredman Dr.',
#         'lat': -26.102274520347056,
#         'lng': 28.05661562171224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102274520347056,
#           'lng': 28.05661562171224}],
#         'distance': 12,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['24 Central (Cnr. Gwen Ln. & Fredman Dr.)',
#          'Sandton',
#          '2196']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d56dde7611aa35d3eb84639-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1e8b00e4b06076a31f668c',
#        'name': '4 merchant place canteen',
#        'location': {'lat': -26.100307275988385,
#         'lng': 28.057695639679366,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.100307275988385,
#           'lng': 28.057695639679366}],
#         'distance': 240,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika'},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1e8b00e4b06076a31f668c-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b707a96f964a520fb1c2de3',
#        'name': 'Tivoli Restaurant',
#        'location': {'address': 'Village Square',
#         'lat': -26.103709723684336,
#         'lng': 28.05846413266099,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103709723684336,
#           'lng': 28.05846413266099}],
#         'distance': 256,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Village Square', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b707a96f964a520fb1c2de3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dedc337d4c0194252ee7ed6',
#        'name': 'Riverside Caffe And Bistro',
#        'location': {'lat': -26.103692461324275,
#         'lng': 28.05853028337701,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103692461324275,
#           'lng': 28.05853028337701}],
#         'distance': 260,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dedc337d4c0194252ee7ed6-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e212b04a80968cf3e3d3b29',
#        'name': 'The Colony',
#        'location': {'lat': -26.10406498549736,
#         'lng': 28.058282007659926,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10406498549736,
#           'lng': 28.058282007659926}],
#         'distance': 272,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e212b04a80968cf3e3d3b29-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bcc6a76345cbe002c2416aa',
#        'name': 'Wok N Roll',
#        'location': {'address': '129 Rivonia Road Corner Maude Street',
#         'crossStreet': 'Rivonia Rd',
#         'lat': -26.103565,
#         'lng': 28.058832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103565,
#           'lng': 28.058832}],
#         'distance': 276,
#         'postalCode': '2031',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['129 Rivonia Road Corner Maude Street (Rivonia Rd)',
#          'EGoli',
#          '2031']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bcc6a76345cbe002c2416aa-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b793e6e492814002ce9d3f9',
#        'name': 'Tashas At The Marc',
#        'location': {'address': 'Rivonia Road',
#         'crossStreet': 'Maude St',
#         'lat': -26.103346,
#         'lng': 28.059063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103346,
#           'lng': 28.059063}],
#         'distance': 283,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Rivonia Road (Maude St)', 'Sandton', '2196']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b793e6e492814002ce9d3f9-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bb399c464c8e1002c386e57',
#        'name': 'Ribs And Burger',
#        'location': {'lat': -26.103453,
#         'lng': 28.059015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103453,
#           'lng': 28.059015}],
#         'distance': 285,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton', '2196']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bb399c464c8e1002c386e57-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058710f964a520fd7d22e3',
#        'name': 'The Blues Room',
#        'location': {'address': 'Corner of Rivonia and Maude streets',
#         'lat': -26.103353,
#         'lng': 28.059286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103353,
#           'lng': 28.059286}],
#         'distance': 304,
#         'postalCode': '2146',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Corner of Rivonia and Maude streets',
#          'EGoli',
#          '2146']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058710f964a520fd7d22e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d50cf51d7eaa143b53b6c0f',
#        'name': 'The Colony, Balalaika',
#        'location': {'lat': -26.104485,
#         'lng': 28.058326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.104485,
#           'lng': 28.058326}],
#         'distance': 311,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika'},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d50cf51d7eaa143b53b6c0f-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55ee9fcd498e544c83588535',
#        'name': 'Trade Winds Restaurant',
#        'location': {'address': '138 Rivera Rd',
#         'lat': -26.10171679754421,
#         'lng': 28.05975168680417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10171679754421,
#           'lng': 28.05975168680417}],
#         'distance': 326,
#         'cc': 'ZA',
#         'city': 'Sandy on',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['138 Rivera Rd', 'Sandy on']},
#        'categories': [{'id': '4bf58dd8d48988d1c8941735',
#          'name': 'African Restaurant',
#          'pluralName': 'African Restaurants',
#          'shortName': 'African',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55ee9fcd498e544c83588535-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ca02c7245f2d4aa8c2c983',
#        'name': 'Lotus Teppanyaki & Sushi Bar',
#        'location': {'address': '138 Rivonia Road',
#         'crossStreet': 'Hilton Sandton',
#         'lat': -26.101805810421535,
#         'lng': 28.05977080814822,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.101805810421535,
#           'lng': 28.05977080814822}],
#         'distance': 326,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'NA',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['138 Rivonia Road (Hilton Sandton)',
#          'Sandton',
#          '2196']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ca02c7245f2d4aa8c2c983-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c0f8e29de3bbf002cdf55bb',
#        'name': 'Kauai The Marc',
#        'location': {'address': 'The Marc Shopping Centre',
#         'crossStreet': 'Shop UR16, Cnr Maude & Rivonia',
#         'lat': -26.103362,
#         'lng': 28.059566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.103362,
#           'lng': 28.059566}],
#         'distance': 330,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['The Marc Shopping Centre (Shop UR16, Cnr Maude & Rivonia)',
#          'Sandton',
#          '2196']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c0f8e29de3bbf002cdf55bb-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c90bf967088a143fbc2aa43',
#        'name': 'Flavours on west',
#        'location': {'address': '155 West Street',
#         'crossStreet': 'Fredman Drive',
#         'lat': -26.10368711392732,
#         'lng': 28.05295023259432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10368711392732,
#           'lng': 28.05295023259432}],
#         'distance': 394,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['155 West Street (Fredman Drive)', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c90bf967088a143fbc2aa43-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc5e45e4a9aa5932b14077b',
#        'name': 'Jewel of india restaurant',
#        'location': {'crossStreet': 'In southern sun hotel',
#         'lat': -26.099042,
#         'lng': 28.058795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.099042,
#           'lng': 28.058795}],
#         'distance': 417,
#         'cc': 'ZA',
#         'city': 'Joburh',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Joburh']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc5e45e4a9aa5932b14077b-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca32abfb0ff8cfa54a4b45e',
#        'name': 'Discovery Snack Shack',
#        'location': {'address': '155 West Street',
#         'lat': -26.104465627988358,
#         'lng': 28.053150763937147,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.104465627988358,
#           'lng': 28.053150763937147}],
#         'distance': 422,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['155 West Street', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca32abfb0ff8cfa54a4b45e-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8a70b1f964a520dc6c32e3',
#        'name': 'The Chairman',
#        'location': {'address': 'Holiday Inn, Sandton',
#         'lat': -26.102767917249263,
#         'lng': 28.06075407503728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102767917249263,
#           'lng': 28.06075407503728}],
#         'distance': 427,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Holiday Inn, Sandton', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8a70b1f964a520dc6c32e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05870ff964a520e07d22e3',
#        'name': 'Tradewinds Restaurant',
#        'location': {'address': '138 Rivonia Road',
#         'lat': -26.102878632164572,
#         'lng': 28.060883708446216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102878632164572,
#           'lng': 28.060883708446216}],
#         'distance': 441,
#         'postalCode': '2196',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['138 Rivonia Road', 'EGoli', '2196']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05870ff964a520e07d22e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501d46eee4b05e0d9577c54e',
#        'name': 'Sandton City, Johannesburg, Gauteng',
#        'location': {'lat': -26.098283934655747,
#         'lng': 28.05747840300057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.098283934655747,
#           'lng': 28.05747840300057}],
#         'distance': 445,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501d46eee4b05e0d9577c54e-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce43f0e42f0b1f7b2448cce',
#        'name': 'Wall Street Restaurant',
#        'location': {'lat': -26.10288656000204,
#         'lng': 28.060970104165055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10288656000204,
#           'lng': 28.060970104165055}],
#         'distance': 450,
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika'},
#        'categories': [{'id': '4bf58dd8d48988d1c8941735',
#          'name': 'African Restaurant',
#          'pluralName': 'African Restaurants',
#          'shortName': 'African',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/african_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce43f0e42f0b1f7b2448cce-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5f87c31939a35d798416ee',
#        'name': 'Subway',
#        'location': {'address': 'Village Walk',
#         'crossStreet': 'Maude Street',
#         'lat': -26.102883955388197,
#         'lng': 28.06098794946023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.102883955388197,
#           'lng': 28.06098794946023}],
#         'distance': 452,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Village Walk (Maude Street)', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5f87c31939a35d798416ee-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd012a941b9ef3b4e79f9e5',
#        'name': "Annica's",
#        'location': {'address': 'Maude Ave',
#         'crossStreet': 'West St.',
#         'lat': -26.10596366370367,
#         'lng': 28.054435287193897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.10596366370367,
#           'lng': 28.054435287193897}],
#         'distance': 469,
#         'cc': 'ZA',
#         'city': 'Sandton',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['Maude Ave (West St.)', 'Sandton']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd012a941b9ef3b4e79f9e5-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c69155535d3be9a6a541e06',
#        'name': 'Fego Caffe Discovery Health',
#        'location': {'address': '3rd Floor, Block B, 16 Fredman Dr, Sandton',
#         'lat': -26.1040704500652,
#         'lng': 28.05228050007675,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -26.1040704500652,
#           'lng': 28.05228050007675}],
#         'distance': 473,
#         'postalCode': '2169',
#         'cc': 'ZA',
#         'city': 'EGoli',
#         'state': 'IGauteng',
#         'country': 'iNingizimu Afrika',
#         'formattedAddress': ['3rd Floor, Block B, 16 Fredman Dr, Sandton',
#          'EGoli',
#          '2169']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c69155535d3be9a6a541e06-33'}]}]}}

# %%
'There are {} Restaurants around the Johannesburg Stock Exchange.'.format(len(results_JSE_food['response']['groups'][0]['items']))
# Out:
# 'There are 34 Restaurants around the Johannesburg Stock Exchange.'

# %%
items_JSE_food = results_JSE_food['response']['groups'][0]['items']
items_JSE_food[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5b79a0f856837a001cbf334c',
#   'name': 'Saint',
#   'location': {'lat': -26.10346672778748,
#    'lng': 28.059072452559565,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': -26.10346672778748,
#      'lng': 28.059072452559565}],
#    'distance': 290,
#    'postalCode': '2196',
#    'cc': 'ZA',
#    'city': 'Sandton',
#    'state': 'IGauteng',
#    'country': 'iNingizimu Afrika',
#    'formattedAddress': ['Sandton', '2196']},
#   'categories': [{'id': '4bf58dd8d48988d110941735',
#     'name': 'Italian Restaurant',
#     'pluralName': 'Italian Restaurants',
#     'shortName': 'Italian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-5b79a0f856837a001cbf334c-0'}

# %%
dataframe_JSE_food = pd.json_normalize(items_JSE_food) # flatten JSON

# %% [markdown]
# ### 3.5.3. Displaying Results for the Restaurants around the Johannesburg Financial District (Johannesburg Stock Exchange) API

# %%
dataframe_JSE_food.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-5b79a0f856837a001cbf334c-0              0
# 1  e-0-4c2cc3cd2219c928209ba648-1              0
# 2  e-0-4be68e7ad4f7c9b63ddf2620-2              0
# 3  e-0-4ba8ff50f964a520ea013ae3-3              0
# 4  e-0-54967e59498e349305cfdbb1-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id      venue.name  venue.location.lat  \
# 0  5b79a0f856837a001cbf334c           Saint          -26.103467
# 1  4c2cc3cd2219c928209ba648  Rocket Express          -26.103396
# 2  4be68e7ad4f7c9b63ddf2620         Pigalle          -26.106063
# 3  4ba8ff50f964a520ea013ae3    The Bull Run          -26.103710
# 4  54967e59498e349305cfdbb1    Knead Bakery          -26.106008
#
#    venue.location.lng                      venue.location.labeledLatLngs  \
# 0           28.059072  [{'label': 'display', 'lat': -26.1034667277874...
# 1           28.058821  [{'label': 'display', 'lat': -26.1033958282770...
# 2           28.054277  [{'label': 'display', 'lat': -26.1060632898311...
# 3           28.058277  [{'label': 'display', 'lat': -26.1037099494713...
# 4           28.054516  [{'label': 'display', 'lat': -26.1060075716839...
#
#    venue.location.distance venue.location.postalCode venue.location.cc  \
# 0                      290                      2196                ZA
# 1                      265                       NaN                ZA
# 2                      486                       NaN                ZA
# 3                      242                       NaN                ZA
# 4                      469                       NaN                ZA
#
#   venue.location.city venue.location.state venue.location.country  \
# 0             Sandton             IGauteng      iNingizimu Afrika
# 1             Sandton             IGauteng      iNingizimu Afrika
# 2             Sandton             IGauteng      iNingizimu Afrika
# 3             Sandton             IGauteng      iNingizimu Afrika
# 4             Sandton             IGauteng      iNingizimu Afrika
#
#          venue.location.formattedAddress  \
# 0                        [Sandton, 2196]
# 1                [Maude Street, Sandton]
# 2                              [Sandton]
# 3  [Maude Street (West Street), Sandton]
# 4                [Maude Street, Sandton]
#
#                                     venue.categories  venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...                   0
# 1  [{'id': '4bf58dd8d48988d1bd941735', 'name': 'S...                   0
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...                   0
# 3  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...                   0
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...                   0
#
#   venue.photos.groups venue.location.address venue.location.crossStreet
# 0                  []                    NaN                        NaN
# 1                  []           Maude Street                        NaN
# 2                  []                    NaN                        NaN
# 3                  []           Maude Street                West Street
# 4                  []           Maude Street                        NaN

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_JSE_food.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_JSE_food = dataframe_JSE_food.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_JSE_food['venue.categories'] = dataframe_filtered_JSE_food.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_JSE_food.columns = [col.split('.')[-1] for col in dataframe_filtered_JSE_food.columns]

dataframe_filtered_JSE_food.head(10)
# Out:
#                                                 name          categories  \
# 0                                              Saint  Italian Restaurant
# 1                                     Rocket Express         Salad Place
# 2                                            Pigalle          Restaurant
# 3                                       The Bull Run          Steakhouse
# 4                                       Knead Bakery              Bakery
# 5                                The Panini Brothers                Café
# 6                             Europa Express Nedbank                Café
# 7  The Gourmet Garage Sandton burgers, steak, rib...        Burger Joint
# 8                                     Fego Caffe RMB                Café
# 9                                       Squires Loft          Steakhouse
#
#          lat        lng                                     labeledLatLngs  \
# 0 -26.103467  28.059072  [{'label': 'display', 'lat': -26.1034667277874...
# 1 -26.103396  28.058821  [{'label': 'display', 'lat': -26.1033958282770...
# 2 -26.106063  28.054277  [{'label': 'display', 'lat': -26.1060632898311...
# 3 -26.103710  28.058277  [{'label': 'display', 'lat': -26.1037099494713...
# 4 -26.106008  28.054516  [{'label': 'display', 'lat': -26.1060075716839...
# 5 -26.101723  28.057038  [{'label': 'display', 'lat': -26.1017232847815...
# 6 -26.102199  28.058406  [{'label': 'display', 'lat': -26.1021987008985...
# 7 -26.102423  28.057541  [{'label': 'display', 'lat': -26.1024230020549...
# 8 -26.100613  28.056982  [{'label': 'display', 'lat': -26.100613, 'lng'...
# 9 -26.102299  28.056577  [{'label': 'display', 'lat': -26.102299, 'lng'...
#
#    distance postalCode  cc     city     state            country  \
# 0       290       2196  ZA  Sandton  IGauteng  iNingizimu Afrika
# 1       265        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 2       486        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 3       242        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 4       469        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 5        72        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 6       187        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
# 7       104       2196  ZA  Sandton  IGauteng  iNingizimu Afrika
# 8       181       2146  ZA  Sandton  IGauteng  iNingizimu Afrika
# 9        12        NaN  ZA  Sandton  IGauteng  iNingizimu Afrika
#
#                                     formattedAddress  \
# 0                                    [Sandton, 2196]
# 1                            [Maude Street, Sandton]
# 2                                          [Sandton]
# 3              [Maude Street (West Street), Sandton]
# 4                            [Maude Street, Sandton]
# 5  [Shop 6, 24 Cenbral (Gwen Lane and Fredman Dri...
# 6                                          [Sandton]
# 7  [24 central, Gwen Lane (Fredman Drive and Gwen...
# 8  [Shop G01, RMB 2 Merchant Place, 1 Fredman Dri...
# 9                              [24 Central, Sandton]
#
#                                            address  \
# 0                                              NaN
# 1                                     Maude Street
# 2                                              NaN
# 3                                     Maude Street
# 4                                     Maude Street
# 5                               Shop 6, 24 Cenbral
# 6                                              NaN
# 7                            24 central, Gwen Lane
# 8  Shop G01, RMB 2 Merchant Place, 1 Fredman Drive
# 9                                       24 Central
#
#                    crossStreet                        id
# 0                          NaN  5b79a0f856837a001cbf334c
# 1                          NaN  4c2cc3cd2219c928209ba648
# 2                          NaN  4be68e7ad4f7c9b63ddf2620
# 3                  West Street  4ba8ff50f964a520ea013ae3
# 4                          NaN  54967e59498e349305cfdbb1
# 5  Gwen Lane and Fredman Drive  51da603a498e78da6c48f58c
# 6                          NaN  4daeabaaa86e29d01a481f5c
# 7  Fredman Drive and Gwen Lane  4ce97033b5c3594163c7698f
# 8                          NaN  4d77bf4e013060fcc7329c05
# 9                          NaN  523c8ea4498ea7e0e8c4e4ba

# %% [markdown]
# ### 3.5.4. Displaying data points of interest from the Data exploration of Restaurants around the Johannesburg Financial District (Johannesburg Stock Exchange) API

# %%
dataframe_JSE_food = dataframe_filtered_JSE_food.iloc [:, 0:8]

# %%
dataframe_JSE_food
# Out:
#                                                  name            categories  \
# 0                                               Saint    Italian Restaurant
# 1                                      Rocket Express           Salad Place
# 2                                             Pigalle            Restaurant
# 3                                        The Bull Run            Steakhouse
# 4                                        Knead Bakery                Bakery
# 5                                 The Panini Brothers                  Café
# 6                              Europa Express Nedbank                  Café
# 7   The Gourmet Garage Sandton burgers, steak, rib...          Burger Joint
# 8                                      Fego Caffe RMB                  Café
# 9                                        Squires Loft            Steakhouse
# 10                                     Gourmet Garage          Burger Joint
# 11                                                 HQ            Steakhouse
# 12                           4 merchant place canteen            Restaurant
# 13                                  Tivoli Restaurant    Italian Restaurant
# 14                         Riverside Caffe And Bistro                  Café
# 15                                         The Colony        Breakfast Spot
# 16                                         Wok N Roll      Asian Restaurant
# 17                                 Tashas At The Marc            Restaurant
# 18                                    Ribs And Burger          Burger Joint
# 19                                     The Blues Room            Restaurant
# 20                              The Colony, Balalaika        Breakfast Spot
# 21                             Trade Winds Restaurant    African Restaurant
# 22                       Lotus Teppanyaki & Sushi Bar            Restaurant
# 23                                     Kauai The Marc  Fast Food Restaurant
# 24                                   Flavours on west             Cafeteria
# 25                          Jewel of india restaurant     Indian Restaurant
# 26                              Discovery Snack Shack           Snack Place
# 27                                       The Chairman            Restaurant
# 28                              Tradewinds Restaurant     Indian Restaurant
# 29                Sandton City, Johannesburg, Gauteng                  Café
# 30                             Wall Street Restaurant    African Restaurant
# 31                                             Subway        Sandwich Place
# 32                                           Annica's            Restaurant
# 33                        Fego Caffe Discovery Health            Restaurant
#
#           lat        lng                                     labeledLatLngs  \
# 0  -26.103467  28.059072  [{'label': 'display', 'lat': -26.1034667277874...
# 1  -26.103396  28.058821  [{'label': 'display', 'lat': -26.1033958282770...
# 2  -26.106063  28.054277  [{'label': 'display', 'lat': -26.1060632898311...
# 3  -26.103710  28.058277  [{'label': 'display', 'lat': -26.1037099494713...
# 4  -26.106008  28.054516  [{'label': 'display', 'lat': -26.1060075716839...
# 5  -26.101723  28.057038  [{'label': 'display', 'lat': -26.1017232847815...
# 6  -26.102199  28.058406  [{'label': 'display', 'lat': -26.1021987008985...
# 7  -26.102423  28.057541  [{'label': 'display', 'lat': -26.1024230020549...
# 8  -26.100613  28.056982  [{'label': 'display', 'lat': -26.100613, 'lng'...
# 9  -26.102299  28.056577  [{'label': 'display', 'lat': -26.102299, 'lng'...
# 10 -26.102236  28.056795  [{'label': 'display', 'lat': -26.1022357870133...
# 11 -26.102275  28.056616  [{'label': 'display', 'lat': -26.1022745203470...
# 12 -26.100307  28.057696  [{'label': 'display', 'lat': -26.1003072759883...
# 13 -26.103710  28.058464  [{'label': 'display', 'lat': -26.1037097236843...
# 14 -26.103692  28.058530  [{'label': 'display', 'lat': -26.1036924613242...
# 15 -26.104065  28.058282  [{'label': 'display', 'lat': -26.1040649854973...
# 16 -26.103565  28.058832  [{'label': 'display', 'lat': -26.103565, 'lng'...
# 17 -26.103346  28.059063  [{'label': 'display', 'lat': -26.103346, 'lng'...
# 18 -26.103453  28.059015  [{'label': 'display', 'lat': -26.103453, 'lng'...
# 19 -26.103353  28.059286  [{'label': 'display', 'lat': -26.103353, 'lng'...
# 20 -26.104485  28.058326  [{'label': 'display', 'lat': -26.104485, 'lng'...
# 21 -26.101717  28.059752  [{'label': 'display', 'lat': -26.1017167975442...
# 22 -26.101806  28.059771  [{'label': 'display', 'lat': -26.1018058104215...
# 23 -26.103362  28.059566  [{'label': 'display', 'lat': -26.103362, 'lng'...
# 24 -26.103687  28.052950  [{'label': 'display', 'lat': -26.1036871139273...
# 25 -26.099042  28.058795  [{'label': 'display', 'lat': -26.099042, 'lng'...
# 26 -26.104466  28.053151  [{'label': 'display', 'lat': -26.1044656279883...
# 27 -26.102768  28.060754  [{'label': 'display', 'lat': -26.1027679172492...
# 28 -26.102879  28.060884  [{'label': 'display', 'lat': -26.1028786321645...
# 29 -26.098284  28.057478  [{'label': 'display', 'lat': -26.0982839346557...
# 30 -26.102887  28.060970  [{'label': 'display', 'lat': -26.1028865600020...
# 31 -26.102884  28.060988  [{'label': 'display', 'lat': -26.1028839553881...
# 32 -26.105964  28.054435  [{'label': 'display', 'lat': -26.1059636637036...
# 33 -26.104070  28.052281  [{'label': 'display', 'lat': -26.1040704500652...
#
#     distance postalCode  cc
# 0        290       2196  ZA
# 1        265        NaN  ZA
# 2        486        NaN  ZA
# 3        242        NaN  ZA
# 4        469        NaN  ZA
# 5         72        NaN  ZA
# 6        187        NaN  ZA
# 7        104       2196  ZA
# 8        181       2146  ZA
# 9         12        NaN  ZA
# 10        26        NaN  ZA
# 11        12       2196  ZA
# 12       240        NaN  ZA
# 13       256        NaN  ZA
# 14       260        NaN  ZA
# 15       272        NaN  ZA
# 16       276       2031  ZA
# 17       283       2196  ZA
# 18       285       2196  ZA
# 19       304       2146  ZA
# 20       311        NaN  ZA
# 21       326        NaN  ZA
# 22       326       2196  ZA
# 23       330       2196  ZA
# 24       394        NaN  ZA
# 25       417        NaN  ZA
# 26       422        NaN  ZA
# 27       427        NaN  ZA
# 28       441       2196  ZA
# 29       445        NaN  ZA
# 30       450        NaN  ZA
# 31       452        NaN  ZA
# 32       469        NaN  ZA
# 33       473       2169  ZA

# %% [markdown]
# ### 3.5.5. Creating a Frequency table for the data exploration of Restaurants around the Johannesburg Financial District (Johannesburg Stock Exchange) API

# %%
dataframe_JSE_food ['categories'].unique()
# Out:
# array(['Italian Restaurant', 'Salad Place', 'Restaurant', 'Steakhouse',
#        'Bakery', 'Café', 'Burger Joint', 'Breakfast Spot',
#        'Asian Restaurant', 'African Restaurant', 'Fast Food Restaurant',
#        'Cafeteria', 'Indian Restaurant', 'Snack Place', 'Sandwich Place'],
#       dtype=object)

# %%
dataframe_JSE_food_categories =  dataframe_JSE_food.groupby('categories')['categories'].size().reset_index(name='counts').sort_values(['counts','categories'],ascending = [False,True])
dataframe_JSE_food_categories
# Out:
#               categories  counts
# 10            Restaurant       8
# 6                   Café       5
# 4           Burger Joint       3
# 14            Steakhouse       3
# 0     African Restaurant       2
# 3         Breakfast Spot       2
# 8      Indian Restaurant       2
# 9     Italian Restaurant       2
# 1       Asian Restaurant       1
# 2                 Bakery       1
# 5              Cafeteria       1
# 7   Fast Food Restaurant       1
# 11           Salad Place       1
# 12        Sandwich Place       1
# 13           Snack Place       1

# %% [markdown]
# ## 3.6 Exploring Restaurants around the Toronto Financial District (Toronto Stock Exchange)

# %% [markdown]
# ### 3.6.1 Running the API to explore Restaurants around the Toronto Stock Exchange

# %%
url_TSX_food = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_2, longitude_2,ACCESS_TOKEN, VERSION, query, radius_1, LIMIT_2)
url_TSX_food
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=XP5V0UWY5UNHLA1PLLNKBCGTZCVKXNQIMFLB5BCTUMN3TXMC&client_secret=C0FGSOMMZL20PS3GZJ24N54TVVQAKMG1HKA1GL1YMPLMQPUU&ll=43.64855,-79.383304&oauth_token=1UUHMKB3ZBYQ3GVUNHWDRV3VFWZPBOT4YEWSTCO0EMXFYW2N&v=20180604&query=Restaurant&radius=500&limit=500'

# %% [markdown]
# ### 3.6.2 Formatting the API results for exploring Restaurants around the Toronto Stock Exchange

# %%
results_TSX_food = requests.get(url_TSX_food).json()
results_TSX_food
# Out:
# {'meta': {'code': 200, 'requestId': '60dd2d00a770ad00183f9f50'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Financial District',
#   'headerFullLocation': 'Financial District, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'restaurant',
#   'totalResults': 166,
#   'suggestedBounds': {'ne': {'lat': 43.6530500045, 'lng': -79.37709659032932},
#    'sw': {'lat': 43.6440499955, 'lng': -79.38951140967067}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad69511f964a520e40721e3',
#        'name': 'The Keg Steakhouse + Bar - York Street',
#        'location': {'address': '165 York St',
#         'crossStreet': 'btwn Richmond St. & Adelaide St.',
#         'lat': 43.64998659318569,
#         'lng': -79.38410336664538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64998659318569,
#           'lng': -79.38410336664538}],
#         'distance': 172,
#         'postalCode': 'M5H 3R8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['165 York St (btwn Richmond St. & Adelaide St.)',
#          'Toronto ON M5H 3R8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359966175'}},
#       'referralId': 'e-0-4ad69511f964a520e40721e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcbf219d22d7ffe9d39197e',
#        'name': 'Brick Street Bakery',
#        'location': {'address': '100 King St W',
#         'crossStreet': 'at Bay St.',
#         'lat': 43.6488151631615,
#         'lng': -79.38060468610949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6488151631615,
#           'lng': -79.38060468610949}],
#         'distance': 219,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King St W (at Bay St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dcbf219d22d7ffe9d39197e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05df964a52059f620e3',
#        'name': 'Canoe',
#        'location': {'address': '66 Wellington St West',
#         'crossStreet': 'at Bay Street',
#         'lat': 43.647452066183476,
#         'lng': -79.38132001815676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647452066183476,
#           'lng': -79.38132001815676}],
#         'distance': 201,
#         'postalCode': 'M5K 1H6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['66 Wellington St West (at Bay Street)',
#          'Toronto ON M5K 1H6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '40552945'}},
#       'referralId': 'e-0-4ad4c05df964a52059f620e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '559a8f5a498e31f945041245',
#        'name': 'Maman',
#        'location': {'address': '100 King St W',
#         'crossStreet': 'btwn Bay & York st',
#         'lat': 43.64830873804684,
#         'lng': -79.38225333898805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64830873804684,
#           'lng': -79.38225333898805}],
#         'distance': 88,
#         'postalCode': 'M5X 1C1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King St W (btwn Bay & York st)',
#          'Toronto ON M5X 1C1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-559a8f5a498e31f945041245-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b6c842bc36588002c80a934',
#        'name': 'Cafe Landwer',
#        'location': {'address': '165 University Ave',
#         'crossStreet': 'Adelaide St W',
#         'lat': 43.64875349932059,
#         'lng': -79.3853673607289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64875349932059,
#           'lng': -79.3853673607289}],
#         'distance': 167,
#         'postalCode': 'M5H 3B8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['165 University Ave (Adelaide St W)',
#          'Toronto ON M5H 3B8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b6c842bc36588002c80a934-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fccaa8fe4b05a98df3d9417',
#        'name': 'Sam James Coffee Bar (SJCB)',
#        'location': {'address': '150 King St. W',
#         'crossStreet': 'in the PATH',
#         'lat': 43.64788137014028,
#         'lng': -79.38433152836829,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64788137014028,
#           'lng': -79.38433152836829}],
#         'distance': 111,
#         'postalCode': 'M5H 4B6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['150 King St. W (in the PATH)',
#          'Toronto ON M5H 4B6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fccaa8fe4b05a98df3d9417-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae7199ff964a52068a821e3',
#        'name': 'Bymark',
#        'location': {'address': '66 Wellington St. W',
#         'crossStreet': 'btwn York & Bay St.',
#         'lat': 43.647217284018005,
#         'lng': -79.38125188166379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647217284018005,
#           'lng': -79.38125188166379}],
#         'distance': 222,
#         'postalCode': 'M5K 1J3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['66 Wellington St. W (btwn York & Bay St.)',
#          'Toronto ON M5K 1J3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae7199ff964a52068a821e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ecb1fae4b0beb13294f0aa',
#        'name': 'John & Sons Oyster House',
#        'location': {'address': '56 Temperance Street',
#         'lat': 43.65065642537144,
#         'lng': -79.38161285228475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65065642537144,
#           'lng': -79.38161285228475}],
#         'distance': 271,
#         'postalCode': 'M5H 3V5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['56 Temperance Street',
#          'Toronto ON M5H 3V5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '122923005'}},
#       'referralId': 'e-0-50ecb1fae4b0beb13294f0aa-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5227fd9d7e48b6c9c707f4fa',
#        'name': 'Astarté Fresh Yogurt Bar',
#        'location': {'address': '150 King Street West',
#         'crossStreet': 'The PATH @ King & University',
#         'lat': 43.647595917807365,
#         'lng': -79.38641938975012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647595917807365,
#           'lng': -79.38641938975012}],
#         'distance': 272,
#         'postalCode': 'M5H 1J9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['150 King Street West (The PATH @ King & University)',
#          'Toronto ON M5H 1J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5227fd9d7e48b6c9c707f4fa-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5462ac56498e128ccafe8fea',
#        'name': 'Pizzeria Libretto',
#        'location': {'address': '155 University Ave',
#         'crossStreet': 'at Pearl St',
#         'lat': 43.64833354686235,
#         'lng': -79.38511050184168,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64833354686235,
#           'lng': -79.38511050184168}],
#         'distance': 147,
#         'postalCode': 'M5H 3B7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['155 University Ave (at Pearl St)',
#          'Toronto ON M5H 3B7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5462ac56498e128ccafe8fea-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b114234f964a520637923e3',
#        'name': "Pumpernickel's Deli",
#        'location': {'address': '100 King St. W',
#         'crossStreet': 'at First Canadian Place Food Court',
#         'lat': 43.64883150054619,
#         'lng': -79.38197006345457,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64883150054619,
#           'lng': -79.38197006345457}],
#         'distance': 111,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King St. W (at First Canadian Place Food Court)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b114234f964a520637923e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd8cde92e6f0f47dcb20808',
#        'name': "Hy's Steakhouse",
#        'location': {'address': '120 Adelaide St. W',
#         'crossStreet': 'at York St',
#         'lat': 43.649504756476944,
#         'lng': -79.38291850488223,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649504756476944,
#           'lng': -79.38291850488223}],
#         'distance': 110,
#         'postalCode': 'M5H 1T1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['120 Adelaide St. W (at York St)',
#          'Toronto ON M5H 1T1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd8cde92e6f0f47dcb20808-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aff06ca6e4650002cc6286b',
#        'name': 'Rosalinda',
#        'location': {'address': '133 Richmond St W',
#         'lat': 43.650252483069295,
#         'lng': -79.38515575620075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650252483069295,
#           'lng': -79.38515575620075}],
#         'distance': 241,
#         'postalCode': 'M5H 2L2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['133 Richmond St W',
#          'Toronto ON M5H 2L2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aff06ca6e4650002cc6286b-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506a3830e4b0677a1f9d8eda',
#        'name': 'Ninki Izakaya',
#        'location': {'address': '133 Richmond Street West',
#         'crossStreet': "Richmond And University's",
#         'lat': 43.65022782352305,
#         'lng': -79.38486260004564,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65022782352305,
#           'lng': -79.38486260004564}],
#         'distance': 225,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["133 Richmond Street West (Richmond And University's)",
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-506a3830e4b0677a1f9d8eda-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50468014e4b01c18bb731df8',
#        'name': 'Bosk at Shangri-La',
#        'location': {'address': '188 University Ave.',
#         'lat': 43.649022736761516,
#         'lng': -79.38582635521233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649022736761516,
#           'lng': -79.38582635521233}],
#         'distance': 209,
#         'postalCode': 'M5H 0A3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['188 University Ave.',
#          'Toronto ON M5H 0A3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50468014e4b01c18bb731df8-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a6bad222632ec473853718a',
#        'name': 'Tachi',
#        'location': {'address': '111 Richmond St W',
#         'crossStreet': 'York St',
#         'lat': 43.65059603893127,
#         'lng': -79.38339613055128,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65059603893127,
#           'lng': -79.38339613055128}],
#         'distance': 227,
#         'postalCode': 'M5H 2G4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['111 Richmond St W (York St)',
#          'Toronto ON M5H 2G4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a6bad222632ec473853718a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae7b370f964a5206ead21e3',
#        'name': 'Petit Four Bakery',
#        'location': {'address': '187 Bay St, Commerce Court South, Concourse Level',
#         'crossStreet': 'at Wellington St W',
#         'lat': 43.647743692587085,
#         'lng': -79.37958814250598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647743692587085,
#           'lng': -79.37958814250598}],
#         'distance': 312,
#         'postalCode': 'M5L 1G5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['187 Bay St, Commerce Court South, Concourse Level (at Wellington St W)',
#          'Toronto ON M5L 1G5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '48813472'}},
#       'referralId': 'e-0-4ae7b370f964a5206ead21e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5321f4d9e4b07946702e6e08',
#        'name': 'Byblos Toronto',
#        'location': {'address': '11 Duncan Street',
#         'lat': 43.647615054171766,
#         'lng': -79.3883810317138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647615054171766,
#           'lng': -79.3883810317138}],
#         'distance': 421,
#         'postalCode': 'M5V 3M2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['11 Duncan Street',
#          'Toronto ON M5V 3M2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5321f4d9e4b07946702e6e08-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e44770e4b0e03a48c0d8a8',
#        'name': 'Kupfert & Kim (First Canadian Place)',
#        'location': {'address': '100 King Street West',
#         'lat': 43.64854659465186,
#         'lng': -79.38162406470161,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64854659465186,
#           'lng': -79.38162406470161}],
#         'distance': 135,
#         'postalCode': 'M5X 1B1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King Street West',
#          'Toronto ON M5X 1B1',
#          'Canada']},
#        'categories': [{'id': '4c2cd86ed066bed06c3c5209',
#          'name': 'Gluten-free Restaurant',
#          'pluralName': 'Gluten-free Restaurants',
#          'shortName': 'Gluten-free',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/glutenfree_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '45671051'}},
#       'referralId': 'e-0-50e44770e4b0e03a48c0d8a8-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52138db911d22803b334c641',
#        'name': 'Mos Mos Coffee',
#        'location': {'address': 'Commerce Court East',
#         'lat': 43.64815919753501,
#         'lng': -79.37874450467258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64815919753501,
#           'lng': -79.37874450467258}],
#         'distance': 369,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Commerce Court East', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52138db911d22803b334c641-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e048b98315168be7fd7ee4d',
#        'name': 'Estiatorio Volos',
#        'location': {'address': '133 Richmond St. W',
#         'crossStreet': 'at York St.',
#         'lat': 43.65032912559998,
#         'lng': -79.38453301297716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65032912559998,
#           'lng': -79.38453301297716}],
#         'distance': 221,
#         'postalCode': 'M5H 2L3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['133 Richmond St. W (at York St.)',
#          'Toronto ON M5H 2L3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '75877391'}},
#       'referralId': 'e-0-4e048b98315168be7fd7ee4d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529612de11d2ab526191ccc9',
#        'name': 'Pai',
#        'location': {'address': '18 Duncan St',
#         'crossStreet': 'Adelaide and Duncan',
#         'lat': 43.64792310735613,
#         'lng': -79.38857932631602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64792310735613,
#           'lng': -79.38857932631602}],
#         'distance': 430,
#         'postalCode': 'M5H 3G6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['18 Duncan St (Adelaide and Duncan)',
#          'Toronto ON M5H 3G6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-529612de11d2ab526191ccc9-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59603f86112c6c70931c9401',
#        'name': 'King Taps',
#        'location': {'address': '100 King St W',
#         'lat': 43.648475974183,
#         'lng': -79.38205778358744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648475974183,
#           'lng': -79.38205778358744}],
#         'distance': 100,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King St W', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359832578'}},
#       'referralId': 'e-0-59603f86112c6c70931c9401-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5057b3d1e4b0e54029a4acc8',
#        'name': "Michael's on Simcoe",
#        'location': {'address': '100 Simcoe St',
#         'crossStreet': 'at Adelaide St',
#         'lat': 43.64826881661747,
#         'lng': -79.38632821234134,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64826881661747,
#           'lng': -79.38632821234134}],
#         'distance': 245,
#         'postalCode': 'M5H 3G2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 Simcoe St (at Adelaide St)',
#          'Toronto ON M5H 3G2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '80039571'}},
#       'referralId': 'e-0-5057b3d1e4b0e54029a4acc8-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514627d1e4b0dba1b85e9ba8',
#        'name': 'Dineen Coffee',
#        'location': {'address': '140 Yonge St',
#         'crossStreet': 'at Temperance St',
#         'lat': 43.650497,
#         'lng': -79.378765,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650497,
#           'lng': -79.378765}],
#         'distance': 425,
#         'postalCode': 'M5C 1X6',
#         'cc': 'CA',
#         'neighborhood': 'Financial District',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['140 Yonge St (at Temperance St)',
#          'Toronto ON M5C 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514627d1e4b0dba1b85e9ba8-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509bb871e4b09c7ac93f6642',
#        'name': 'JaBistro',
#        'location': {'address': '222 Richmond St W',
#         'lat': 43.64968685893743,
#         'lng': -79.38809001547467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64968685893743,
#           'lng': -79.38809001547467}],
#         'distance': 405,
#         'postalCode': 'M5V 1W4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['222 Richmond St W',
#          'Toronto ON M5V 1W4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509bb871e4b09c7ac93f6642-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fc571f498ec35023360858',
#        'name': 'Cactus Club Cafe',
#        'location': {'address': '77 Adelaide St W',
#         'crossStreet': 'btwn Bay & York St',
#         'lat': 43.6495520142626,
#         'lng': -79.38167072512041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6495520142626,
#           'lng': -79.38167072512041}],
#         'distance': 172,
#         'postalCode': 'M5X 1C1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['77 Adelaide St W (btwn Bay & York St)',
#          'Toronto ON M5X 1C1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359832577'}},
#       'referralId': 'e-0-55fc571f498ec35023360858-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afa1f33f964a520e91622e3',
#        'name': 'Fune Japanese Restaurant',
#        'location': {'address': '100 Simcoe St.',
#         'crossStreet': 'at Pearl St.',
#         'lat': 43.64851365544565,
#         'lng': -79.38645657820041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64851365544565,
#           'lng': -79.38645657820041}],
#         'distance': 253,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 Simcoe St. (at Pearl St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afa1f33f964a520e91622e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506db1a9e4b0a3f3b31412f0',
#        'name': 'Richmond Station',
#        'location': {'address': '1 Richmond Street West',
#         'crossStreet': 'Yonge Street',
#         'lat': 43.65156872562108,
#         'lng': -79.37926594000328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65156872562108,
#           'lng': -79.37926594000328}],
#         'distance': 467,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Richmond Street West (Yonge Street)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-506db1a9e4b0a3f3b31412f0-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ae5eaa498e5c629f21f431',
#        'name': "Olly Fresco's",
#        'location': {'address': '200 Bay Street',
#         'lat': 43.646912231909276,
#         'lng': -79.37959661696463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646912231909276,
#           'lng': -79.37959661696463}],
#         'distance': 349,
#         'postalCode': 'M5J 2J3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200 Bay Street',
#          'Toronto ON M5J 2J3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69531383'}},
#       'referralId': 'e-0-51ae5eaa498e5c629f21f431-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c524bd498efaeebf73b291',
#        'name': 'Café Plenty',
#        'location': {'address': '1 King St W',
#         'crossStreet': 'Yonge St',
#         'lat': 43.6491179354577,
#         'lng': -79.37831288380438,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6491179354577,
#           'lng': -79.37831288380438}],
#         'distance': 406,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 King St W (Yonge St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c524bd498efaeebf73b291-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5214e7c111d2a83379eae21f',
#        'name': 'The Chase',
#        'location': {'address': '10 Temperance St fl 5',
#         'crossStreet': 'Yonge St',
#         'lat': 43.650951982093595,
#         'lng': -79.37942201983014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650951982093595,
#           'lng': -79.37942201983014}],
#         'distance': 411,
#         'postalCode': 'M5H 1Y4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['10 Temperance St fl 5 (Yonge St)',
#          'Toronto ON M5H 1Y4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5214e7c111d2a83379eae21f-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bacf405f964a520881d3be3',
#        'name': "Druxy's",
#        'location': {'address': '199 Bay St',
#         'crossStreet': 'Wellington',
#         'lat': 43.648015481211395,
#         'lng': -79.37990651776452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648015481211395,
#           'lng': -79.37990651776452}],
#         'distance': 280,
#         'postalCode': 'M5L 1G5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['199 Bay St (Wellington)',
#          'Toronto ON M5L 1G5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bacf405f964a520881d3be3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5076f901e4b024f6d6140860',
#        'name': 'Subway',
#        'location': {'address': '150 King St W, Unit P1-1',
#         'crossStreet': 'in Sun Life Financial Tower',
#         'lat': 43.647961982409484,
#         'lng': -79.38422441482544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647961982409484,
#           'lng': -79.38422441482544}],
#         'distance': 98,
#         'postalCode': 'M5H 1J9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['150 King St W, Unit P1-1 (in Sun Life Financial Tower)',
#          'Toronto ON M5H 1J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5076f901e4b024f6d6140860-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a4fdf56772fbc5e9fa73c7f',
#        'name': 'Chotto Matte',
#        'location': {'address': '161 Bay St',
#         'lat': 43.646473,
#         'lng': -79.378782,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646473,
#           'lng': -79.378782}],
#         'distance': 431,
#         'postalCode': 'M5J 2S4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['161 Bay St', 'Toronto ON M5J 2S4', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a4fdf56772fbc5e9fa73c7f-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba24e76f964a520aceb37e3',
#        'name': 'Sushi-Q',
#        'location': {'address': '199 Bay',
#         'crossStreet': 'Commerce Court',
#         'lat': 43.64773753191116,
#         'lng': -79.37969913096782,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64773753191116,
#           'lng': -79.37969913096782}],
#         'distance': 304,
#         'postalCode': 'M5H 1T1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['199 Bay (Commerce Court)',
#          'Toronto ON M5H 1T1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba24e76f964a520aceb37e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bb797b8bf7dde002c2cdbfa',
#        'name': 'Aroma Espresso Bar',
#        'location': {'address': '40 King Street West',
#         'crossStreet': 'PATH',
#         'lat': 43.64907,
#         'lng': -79.38004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64907,
#           'lng': -79.38004}],
#         'distance': 269,
#         'postalCode': 'M5H 1H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 King Street West (PATH)',
#          'Toronto ON M5H 1H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bb797b8bf7dde002c2cdbfa-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573b65fb498e9bcba6b1089a',
#        'name': 'Five Guys',
#        'location': {'address': '100 King St. West, Space 93',
#         'lat': 43.6487987190222,
#         'lng': -79.3816807899204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6487987190222,
#           'lng': -79.3816807899204}],
#         'distance': 133,
#         'postalCode': 'M5X 1A9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 King St. West, Space 93',
#          'Toronto ON M5X 1A9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-573b65fb498e9bcba6b1089a-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae73054f964a5203ca921e3',
#        'name': 'Ki Modern Japanese + Bar',
#        'location': {'address': '181 Bay St',
#         'crossStreet': 'at Wellington St. W',
#         'lat': 43.647223,
#         'lng': -79.3793738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647223,
#           'lng': -79.3793738}],
#         'distance': 349,
#         'postalCode': 'M5J 2T3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['181 Bay St (at Wellington St. W)',
#          'Toronto ON M5J 2T3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae73054f964a5203ca921e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a5a59c5a423620ec1dafd41',
#        'name': 'Pi Co.',
#        'location': {'address': '170 University Ave',
#         'crossStreet': 'Adelaide St W',
#         'lat': 43.648651,
#         'lng': -79.385874,
# ...
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57793907'}},
#       'referralId': 'e-0-4ad8a5a7f964a5203c1321e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c890b1f94f5a093c3a8d41e',
#        'name': 'Subway',
#        'location': {'address': '127 Yonge St',
#         'lat': 43.6509705,
#         'lng': -79.3783317,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6509705,
#           'lng': -79.3783317}],
#         'distance': 482,
#         'postalCode': 'M5C 1W5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['127 Yonge St', 'Toronto ON M5C 1W5', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c890b1f94f5a093c3a8d41e-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a25803498e7d4b58e348a4',
#        'name': 'Crave Healthy Habits',
#        'location': {'address': '145 King St West',
#         'crossStreet': 'King & York Concourse Level',
#         'lat': 43.647717,
#         'lng': -79.383916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647717,
#           'lng': -79.383916}],
#         'distance': 105,
#         'postalCode': 'M5H 1J8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 King St West (King & York Concourse Level)',
#          'Toronto ON M5H 1J8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62772226'}},
#       'referralId': 'e-0-51a25803498e7d4b58e348a4-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d756edfbf4fb1f74fe8722a',
#        'name': 'iQ Food Co.',
#        'location': {'address': '100 Wellington St W',
#         'crossStreet': 'in TD Centre Food Court',
#         'lat': 43.64710700159061,
#         'lng': -79.3824148923304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64710700159061,
#           'lng': -79.3824148923304}],
#         'distance': 175,
#         'postalCode': 'M5K 1B1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 Wellington St W (in TD Centre Food Court)',
#          'Toronto ON M5K 1B1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d756edfbf4fb1f74fe8722a-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7a6212e8b7a1cdb919971f',
#        'name': 'Szechuan Express',
#        'location': {'address': '200 Bay St.',
#         'crossStreet': 'in Royal Bank Plaza',
#         'lat': 43.6469728132212,
#         'lng': -79.37954884053248,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6469728132212,
#           'lng': -79.37954884053248}],
#         'distance': 349,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['200 Bay St. (in Royal Bank Plaza)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7a6212e8b7a1cdb919971f-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c87c8260dcb8cfabfd83d68',
#        'name': 'Burger King',
#        'location': {'address': '130 King St West',
#         'crossStreet': 'in Exchange Tower',
#         'lat': 43.6489639,
#         'lng': -79.3836288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6489639,
#           'lng': -79.3836288}],
#         'distance': 52,
#         'postalCode': 'M5X 1A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['130 King St West (in Exchange Tower)',
#          'Toronto ON M5X 1A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c87c8260dcb8cfabfd83d68-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0f2414c3658815295727a5',
#        'name': 'The Danish Pastry House',
#        'location': {'address': '65 Front St W',
#         'crossStreet': 'York',
#         'lat': 43.64526188121351,
#         'lng': -79.38084966956498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64526188121351,
#           'lng': -79.38084966956498}],
#         'distance': 416,
#         'postalCode': 'M5X 4A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['65 Front St W (York)',
#          'Toronto ON M5X 4A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a0f2414c3658815295727a5-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59b30028ee71203bd8fbb85d',
#        'name': 'PLANTA Burger Financial District',
#        'location': {'address': '4 Temperance St',
#         'lat': 43.65093442906692,
#         'lng': -79.37929871929829,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65093442906692,
#           'lng': -79.37929871929829}],
#         'distance': 417,
#         'postalCode': 'M5H 1Y4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['4 Temperance St',
#          'Toronto ON M5H 1Y4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59b30028ee71203bd8fbb85d-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bd1248e4b0382138bdd292',
#        'name': 'iQ Food Co',
#        'location': {'address': '181 Bay St.',
#         'crossStreet': 'in Brookfield Place',
#         'lat': 43.64748168603231,
#         'lng': -79.37910417362639,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64748168603231,
#           'lng': -79.37910417362639}],
#         'distance': 358,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['181 Bay St. (in Brookfield Place)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50bd1248e4b0382138bdd292-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b13f903f964a5201c9b23e3',
#        'name': 'Wendy’s',
#        'location': {'address': '55 University Avenue',
#         'lat': 43.6466603,
#         'lng': -79.3838784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6466603,
#           'lng': -79.3838784}],
#         'distance': 215,
#         'postalCode': 'M5J 2H7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 University Avenue',
#          'Toronto ON M5J 2H7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b13f903f964a5201c9b23e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7cd9cab8037ccb8bae7da5',
#        'name': 'Modus Ristorante',
#        'location': {'address': '145 King St W',
#         'crossStreet': 'York',
#         'lat': 43.64762079256355,
#         'lng': -79.38335022554688,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64762079256355,
#           'lng': -79.38335022554688}],
#         'distance': 103,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['145 King St W (York)', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7cd9cab8037ccb8bae7da5-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2a8485f964a520abaa24e3',
#        'name': 'Subway',
#        'location': {'address': '60 Yonge St, Unit 65',
#         'crossStreet': 'at Wellington St',
#         'lat': 43.64830041435992,
#         'lng': -79.37784568636562,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64830041435992,
#           'lng': -79.37784568636562}],
#         'distance': 440,
#         'postalCode': 'M5E 1H5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['60 Yonge St, Unit 65 (at Wellington St)',
#          'Toronto ON M5E 1H5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2a8485f964a520abaa24e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e186b29183880768f406e17',
#        'name': 'Sunset Grill',
#        'location': {'address': '1 Richmond St. W.',
#         'crossStreet': 'at Yonge St.',
#         'lat': 43.65166162378037,
#         'lng': -79.3790751303271,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65166162378037,
#           'lng': -79.3790751303271}],
#         'distance': 485,
#         'postalCode': 'M5H 3W4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 Richmond St. W. (at Yonge St.)',
#          'Toronto ON M5H 3W4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e186b29183880768f406e17-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582e3fa85e56b4259dc5f751',
#        'name': 'Lee Chen Asian Bistro',
#        'location': {'address': '214 King St W',
#         'crossStreet': 'Simcoe St',
#         'lat': 43.64700977986747,
#         'lng': -79.38653557408938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64700977986747,
#           'lng': -79.38653557408938}],
#         'distance': 311,
#         'postalCode': 'M5H 3S6',
#         'cc': 'CA',
#         'neighborhood': 'Entertainment District, Toronto, ON',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['214 King St W (Simcoe St)',
#          'Toronto ON M5H 3S6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582e3fa85e56b4259dc5f751-99'}]}]}}

# %%
'There are {} Restaurants around the Toronto Stock Exchange.'.format(len(results_TSX_food['response']['groups'][0]['items']))
# Out:
# 'There are 100 Restaurants around the Toronto Stock Exchange.'

# %%
items_TSX_food = results_TSX_food['response']['groups'][0]['items']
items_TSX_food[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ad69511f964a520e40721e3',
#   'name': 'The Keg Steakhouse + Bar - York Street',
#   'location': {'address': '165 York St',
#    'crossStreet': 'btwn Richmond St. & Adelaide St.',
#    'lat': 43.64998659318569,
#    'lng': -79.38410336664538,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.64998659318569,
#      'lng': -79.38410336664538}],
#    'distance': 172,
#    'postalCode': 'M5H 3R8',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['165 York St (btwn Richmond St. & Adelaide St.)',
#     'Toronto ON M5H 3R8',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d1c4941735',
#     'name': 'Restaurant',
#     'pluralName': 'Restaurants',
#     'shortName': 'Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '1359966175'}},
#  'referralId': 'e-0-4ad69511f964a520e40721e3-0'}

# %%
dataframe_TSX_food = pd.json_normalize(items_TSX_food) # flatten JSON

# %% [markdown]
# ### 3.6.3 Displaying the API results for exploring Restaurants around the Toronto Stock Exchange

# %%
dataframe_TSX_food.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4ad69511f964a520e40721e3-0              0
# 1  e-0-4dcbf219d22d7ffe9d39197e-1              0
# 2  e-0-4ad4c05df964a52059f620e3-2              0
# 3  e-0-559a8f5a498e31f945041245-3              0
# 4  e-0-5b6c842bc36588002c80a934-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                              venue.name  \
# 0  4ad69511f964a520e40721e3  The Keg Steakhouse + Bar - York Street
# 1  4dcbf219d22d7ffe9d39197e                     Brick Street Bakery
# 2  4ad4c05df964a52059f620e3                                   Canoe
# 3  559a8f5a498e31f945041245                                   Maman
# 4  5b6c842bc36588002c80a934                            Cafe Landwer
#
#   venue.location.address        venue.location.crossStreet  \
# 0            165 York St  btwn Richmond St. & Adelaide St.
# 1          100 King St W                        at Bay St.
# 2  66 Wellington St West                     at Bay Street
# 3          100 King St W                btwn Bay & York st
# 4     165 University Ave                     Adelaide St W
#
#    venue.location.lat  venue.location.lng  \
# 0           43.649987          -79.384103
# 1           43.648815          -79.380605
# 2           43.647452          -79.381320
# 3           43.648309          -79.382253
# 4           43.648753          -79.385367
#
#                        venue.location.labeledLatLngs  ...  venue.location.cc  \
# 0  [{'label': 'display', 'lat': 43.64998659318569...  ...                 CA
# 1  [{'label': 'display', 'lat': 43.6488151631615,...  ...                 CA
# 2  [{'label': 'display', 'lat': 43.64745206618347...  ...                 CA
# 3  [{'label': 'display', 'lat': 43.64830873804684...  ...                 CA
# 4  [{'label': 'display', 'lat': 43.64875349932059...  ...                 CA
#
#   venue.location.city venue.location.state venue.location.country  \
# 0             Toronto                   ON                 Canada
# 1             Toronto                   ON                 Canada
# 2             Toronto                   ON                 Canada
# 3             Toronto                   ON                 Canada
# 4             Toronto                   ON                 Canada
#
#                      venue.location.formattedAddress  \
# 0  [165 York St (btwn Richmond St. & Adelaide St....
# 1   [100 King St W (at Bay St.), Toronto ON, Canada]
# 2  [66 Wellington St West (at Bay Street), Toront...
# 3  [100 King St W (btwn Bay & York st), Toronto O...
# 4  [165 University Ave (Adelaide St W), Toronto O...
#
#                                     venue.categories venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...                  0
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...                  0
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...                  0
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...                  0
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...                  0
#
#   venue.photos.groups  venue.venuePage.id venue.location.neighborhood
# 0                  []          1359966175                         NaN
# 1                  []                 NaN                         NaN
# 2                  []            40552945                         NaN
# 3                  []                 NaN                         NaN
# 4                  []                 NaN                         NaN
#
# [5 rows x 22 columns]

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe_TSX_food.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered_TSX_food = dataframe_TSX_food.loc[:, filtered_columns]


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered_TSX_food['venue.categories'] = dataframe_filtered_TSX_food.apply(get_category_type, axis=1)


# clean columns
dataframe_filtered_TSX_food.columns = [col.split('.')[-1] for col in dataframe_filtered_TSX_food.columns]

dataframe_filtered_TSX_food.head(10)
# Out:
#                                      name          categories  \
# 0  The Keg Steakhouse + Bar - York Street          Restaurant
# 1                     Brick Street Bakery              Bakery
# 2                                   Canoe          Restaurant
# 3                                   Maman                Café
# 4                            Cafe Landwer                Café
# 5             Sam James Coffee Bar (SJCB)                Café
# 6                                  Bymark          Restaurant
# 7                John & Sons Oyster House  Seafood Restaurant
# 8                Astarté Fresh Yogurt Bar                Café
# 9                       Pizzeria Libretto         Pizza Place
#
#                  address                       crossStreet        lat  \
# 0            165 York St  btwn Richmond St. & Adelaide St.  43.649987
# 1          100 King St W                        at Bay St.  43.648815
# 2  66 Wellington St West                     at Bay Street  43.647452
# 3          100 King St W                btwn Bay & York st  43.648309
# 4     165 University Ave                     Adelaide St W  43.648753
# 5         150 King St. W                       in the PATH  43.647881
# 6    66 Wellington St. W               btwn York & Bay St.  43.647217
# 7   56 Temperance Street                               NaN  43.650656
# 8   150 King Street West      The PATH @ King & University  43.647596
# 9     155 University Ave                       at Pearl St  43.648334
#
#          lng                                     labeledLatLngs  distance  \
# 0 -79.384103  [{'label': 'display', 'lat': 43.64998659318569...       172
# 1 -79.380605  [{'label': 'display', 'lat': 43.6488151631615,...       219
# 2 -79.381320  [{'label': 'display', 'lat': 43.64745206618347...       201
# 3 -79.382253  [{'label': 'display', 'lat': 43.64830873804684...        88
# 4 -79.385367  [{'label': 'display', 'lat': 43.64875349932059...       167
# 5 -79.384332  [{'label': 'display', 'lat': 43.64788137014028...       111
# 6 -79.381252  [{'label': 'display', 'lat': 43.64721728401800...       222
# 7 -79.381613  [{'label': 'display', 'lat': 43.65065642537144...       271
# 8 -79.386419  [{'label': 'display', 'lat': 43.64759591780736...       272
# 9 -79.385111  [{'label': 'display', 'lat': 43.64833354686235...       147
#
#   postalCode  cc     city state country  \
# 0    M5H 3R8  CA  Toronto    ON  Canada
# 1        NaN  CA  Toronto    ON  Canada
# 2    M5K 1H6  CA  Toronto    ON  Canada
# 3    M5X 1C1  CA  Toronto    ON  Canada
# 4    M5H 3B8  CA  Toronto    ON  Canada
# 5    M5H 4B6  CA  Toronto    ON  Canada
# 6    M5K 1J3  CA  Toronto    ON  Canada
# 7    M5H 3V5  CA  Toronto    ON  Canada
# 8    M5H 1J9  CA  Toronto    ON  Canada
# 9    M5H 3B7  CA  Toronto    ON  Canada
#
#                                     formattedAddress neighborhood  \
# 0  [165 York St (btwn Richmond St. & Adelaide St....          NaN
# 1   [100 King St W (at Bay St.), Toronto ON, Canada]          NaN
# 2  [66 Wellington St West (at Bay Street), Toront...          NaN
# 3  [100 King St W (btwn Bay & York st), Toronto O...          NaN
# 4  [165 University Ave (Adelaide St W), Toronto O...          NaN
# 5  [150 King St. W (in the PATH), Toronto ON M5H ...          NaN
# 6  [66 Wellington St. W (btwn York & Bay St.), To...          NaN
# 7  [56 Temperance Street, Toronto ON M5H 3V5, Can...          NaN
# 8  [150 King Street West (The PATH @ King & Unive...          NaN
# 9  [155 University Ave (at Pearl St), Toronto ON ...          NaN
#
#                          id
# 0  4ad69511f964a520e40721e3
# 1  4dcbf219d22d7ffe9d39197e
# 2  4ad4c05df964a52059f620e3
# 3  559a8f5a498e31f945041245
# 4  5b6c842bc36588002c80a934
# 5  4fccaa8fe4b05a98df3d9417
# 6  4ae7199ff964a52068a821e3
# 7  50ecb1fae4b0beb13294f0aa
# 8  5227fd9d7e48b6c9c707f4fa
# 9  5462ac56498e128ccafe8fea

# %% [markdown]
# ### 3.6.4 Displaying API results Points of Interest from exploring Restaurants around the Toronto Stock Exchange

# %%
dataframe_TSX_food = dataframe_filtered_TSX_food.iloc [:, 0:8]

# %%
dataframe_TSX_food
# Out:
#                                       name            categories  \
# 0   The Keg Steakhouse + Bar - York Street            Restaurant
# 1                      Brick Street Bakery                Bakery
# 2                                    Canoe            Restaurant
# 3                                    Maman                  Café
# 4                             Cafe Landwer                  Café
# ..                                     ...                   ...
# 95                                 Wendy’s  Fast Food Restaurant
# 96                        Modus Ristorante    Italian Restaurant
# 97                                  Subway            Restaurant
# 98                            Sunset Grill        Breakfast Spot
# 99                   Lee Chen Asian Bistro      Asian Restaurant
#
#                   address                       crossStreet        lat  \
# 0             165 York St  btwn Richmond St. & Adelaide St.  43.649987
# 1           100 King St W                        at Bay St.  43.648815
# 2   66 Wellington St West                     at Bay Street  43.647452
# 3           100 King St W                btwn Bay & York st  43.648309
# 4      165 University Ave                     Adelaide St W  43.648753
# ..                    ...                               ...        ...
# 95   55 University Avenue                               NaN  43.646660
# 96          145 King St W                              York  43.647621
# 97   60 Yonge St, Unit 65                  at Wellington St  43.648300
# 98      1 Richmond St. W.                      at Yonge St.  43.651662
# 99          214 King St W                         Simcoe St  43.647010
#
#           lng                                     labeledLatLngs  distance
# 0  -79.384103  [{'label': 'display', 'lat': 43.64998659318569...       172
# 1  -79.380605  [{'label': 'display', 'lat': 43.6488151631615,...       219
# 2  -79.381320  [{'label': 'display', 'lat': 43.64745206618347...       201
# 3  -79.382253  [{'label': 'display', 'lat': 43.64830873804684...        88
# 4  -79.385367  [{'label': 'display', 'lat': 43.64875349932059...       167
# ..        ...                                                ...       ...
# 95 -79.383878  [{'label': 'display', 'lat': 43.6466603, 'lng'...       215
# 96 -79.383350  [{'label': 'display', 'lat': 43.64762079256355...       103
# 97 -79.377846  [{'label': 'display', 'lat': 43.64830041435992...       440
# 98 -79.379075  [{'label': 'display', 'lat': 43.65166162378037...       485
# 99 -79.386536  [{'label': 'display', 'lat': 43.64700977986747...       311
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 3.6.5 Displaying Frequency results from the API results for exploring Restaurants around the Toronto Stock Exchange

# %%
dataframe_TSX_food_categories =  dataframe_TSX_food.groupby('categories')['categories'].size().reset_index(name='counts').sort_values(['counts','categories'],ascending = [False,True])
dataframe_TSX_food_categories
# Out:
#                        categories  counts
# 26                     Restaurant      14
# 8                            Café       9
# 1                Asian Restaurant       5
# 11                  Deli / Bodega       5
# 12           Fast Food Restaurant       5
# 28                 Sandwich Place       5
# 3                          Bakery       4
# 20            Japanese Restaurant       4
# 32               Sushi Restaurant       4
# 6                    Burger Joint       3
# 7                   Burrito Place       3
# 19             Italian Restaurant       3
# 27                    Salad Place       3
# 31                     Steakhouse       3
# 34  Vegetarian / Vegan Restaurant       3
# 0             American Restaurant       2
# 5                  Breakfast Spot       2
# 9              Chinese Restaurant       2
# 13                     Food Court       2
# 15                      Gastropub       2
# 24                    Pizza Place       2
# 33                Thai Restaurant       2
# 2                      Bagel Shop       1
# 4            Brazilian Restaurant       1
# 10           Colombian Restaurant       1
# 14            Fried Chicken Joint       1
# 16         Gluten-free Restaurant       1
# 17               Greek Restaurant       1
# 18              Indian Restaurant       1
# 21       Mediterranean Restaurant       1
# 22             Mexican Restaurant       1
# 23        New American Restaurant       1
# 25               Ramen Restaurant       1
# 29             Seafood Restaurant       1
# 30                     Soup Place       1

# %% [markdown]
# # 4. Discussion

# %% [markdown]
# Buildings around Financial Centres
# Explorations of the buildings around the Johannesburg Stock Exchange revealed 6 buildings of interest with 66% of them being Hotels and the remaining buildings being a shopping Mall and Wall Street restaurant. Exploration the buildings around the Toronto Stock exchange revealed 65 buildings with diverse categories of which only 12% of them was hotels. Though in terms of percentage Toronto’s number is low in terms of quantity it is still more than Johannesburg’s. Toronto also offer 41 more categories that I was not able to find in the Johannesburg data.
#
# Exploration of entertainment areas around Johannesburg only reveal 4 spots with only two categories being a nightclub and general entertainment. For the same category Toronto offers 42 areas of entertainments, offering visitors variety of things to do and explore around the Financial District. In terms of the categories of entertainment Toronto has 25 (60%) venues categorised under general entertainment. 40% of offer alternative categories which are not found around the Johannesburg Financial district area.
#
# Exploration to the food market in both cities, indicate that there are 34 restaurant around the Johannesburg stock exchange  compared to more than 100 around the Toronto Stock exchange. There is 32 categories of restaurants in the Toronto Stock exchange area compared to 15 around the Johannesburg stock exchange. Though Johannesburg offers fewer restaurants there is more variety in this category for visitors to the area than in any other category explored in this study.

# %% [markdown]
# # 5. Recommendation

# %% [markdown]
# The data does indicate low levels of maturity especially for the Johannesburg data where there were no Office building categories which is a little hard to fathom considering that Johannesburg is the Financial hub of the country of South Africa. As such, I do recommend adding that the provider finds a way to get more data points.
#
# The City of Toronto has more categories of buildings and entertainment areas indicating that there is more points of interest for both visitors and investors. This number of interests do indicate that people are likely to spend in the neighbourhood. Recommendation would be for Johannesburg to invest in more diverse buildings so as to create more interest in the city for people to spend more on the local economy.

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# Toronto does offer variety of areas of interests, entertainment, and restaurants compared to Johannesburg. People visiting the Toronto exchange neighbourhood are likely to spend more time in the area as well as their money compared to Johannesburg. Opportunities of enriched experience are therefore more in the Toronto area compared to Johannesburg.
